# %%
import pandas as pd
import numpy as np
import collections

from sklearn import preprocessing
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, RobustScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_classif
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import RepeatedStratifiedKFold

import datetime


import seaborn as sns
import logging
import csv

import matplotlib
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

font = {'family' : 'normal',
        'size'   : 13}

matplotlib.rc('font', **font)

# %% [markdown]
# # About the data set

# %% [markdown]
# This data set contains 416 liver patient records and 167 non liver patient records.The data set was collected from north east of Andhra Pradesh, India. Selector is a class label used to divide into groups(liver patient or not). This data set contains 441 male patient records and 142 female patient records.
#
# Any patient whose age exceeded 89 is listed as being of age "90".
#
# ## Attributes
# 1. Age - Age of the patient
# 2. Gender - Gender of the patient
# 3. TB - Total Bilirubin
# 4. DB - Direct Bilirubin
# 5. Alkphos - Alkaline Phosphotase
# 6. Sgpt - Alamine Aminotransferase
# 7. Sgot - Aspartate Aminotransferase
# 8. TP - Total Protiens
# 9. ALB - Albumin
# 10. A/G Ratio - Albumin and Globulin Ratio
# 11. Selector field used to split the data into two sets (labeled by the experts)

# %% [markdown]
# # Read the data

# %%
# dataset location
dataset_location = "./dataset/ilpd_dataset.csv"

# column names
names = ['Age', 'Gender', 'TB', 'DB', 'ALKPHOS', 'SGPT', 'SGOT', 'TP', 'ALB', 'AG Ratio', 'selector']

# read dataset to pandas dataframe
df = pd.read_csv(dataset_location, names=names);

# %% [markdown]
# # Data analysis

# %%
# show first five cols of the dataset
print("Data shape: ", df.shape)
df.head()
# Out:
# Data shape:  (583, 11)
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio  selector
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3      0.90         1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2      0.74         1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3      0.89         1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4      1.00         1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4      0.40         1

# %%
# check for null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       583 non-null    int64
#  1   Gender    583 non-null    object
#  2   TB        583 non-null    float64
#  3   DB        583 non-null    float64
#  4   ALKPHOS   583 non-null    int64
#  5   SGPT      583 non-null    int64
#  6   SGOT      583 non-null    int64
#  7   TP        583 non-null    float64
#  8   ALB       583 non-null    float64
#  9   AG Ratio  579 non-null    float64
#  10  selector  583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %% [markdown]
# ## Histograms

# %%
df.hist(figsize=(14,11))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a16548350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18599d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a185dc510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1860fd10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18650550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18685d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a186c6590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a186fbd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a187038d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a18745290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a187ae610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a187e2dd0>]],
#       dtype=object)
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Compare number of samples

# %%
# show number of examples in each class
numb_of_classes = pd.value_counts(df['selector'], sort = True).sort_index()
numb_of_classes.plot(kind = 'bar')
plt.title("Number of examples for each class")
plt.xlabel("Selector")
plt.ylabel("Number of sample")
plt.savefig("./png_results/compare-numb-of-samples.png", dpi=300)

# %%
# show number of examples of each gender
numb_of_classes = pd.value_counts(df['Gender'], sort = True).sort_index()
numb_of_classes.plot(kind = 'bar')
plt.title("Number of examples for each gender")
plt.xlabel("Gender")
plt.ylabel("Number of samples")
plt.savefig("./png_results/compare-genders.png", dpi=300)

# %% [markdown]
# ## Compare mean features of each category

# %%
data1 = df[df['selector'] == 2] # no disease
data1 = data1[data1['Gender'] == 'Female']
data1 = data1.iloc[:,:-1]

data2 = df[df['selector'] == 1] # disease
data2 = data2[data2['Gender'] == 'Female']
data2 = data2.iloc[:,:-1]

fig = plt.figure(figsize=(10,15))

# people without disease
ax1 = fig.add_subplot(211)
ax1.grid()
ax1.set_title('Mean values of each feature (Females)',fontsize=13, weight='bold')
ax1.text(200,0.8,'liver patient',fontsize=20,horizontalalignment='center', color='orange', weight='bold')

plt.sca(ax1)

# people with disease
ax2 = fig.add_subplot(212,sharex=ax1)
ax2.grid()
ax2.set_title('Mean values of each feature (Female)',fontsize=13,weight='bold')
ax2.text(200,0.8,'non liver patient',fontsize=20,horizontalalignment='center',color='green',weight='bold')

plt.sca(ax2)

# show plots
sns.barplot(data=data1,ax=ax1,orient='horizontal', palette='bright')
sns.barplot(data=data2,ax=ax2,orient='horizontal', palette='bright')

fig.savefig("./png_results/patient-vs-nonpatient-features.png", dpi=300)
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
data1 = df[df['selector'] == 2] # no disease
data1 = data1[data1['Gender'] == 'Male']
data1 = data1.iloc[:,:-1]

data2 = df[df['selector'] == 1] # disease
data2 = data2[data2['Gender'] == 'Male']
data2 = data2.iloc[:,:-1]

fig = plt.figure(figsize=(10,15))

# people without disease
ax1 = fig.add_subplot(211)
ax1.grid()
ax1.set_title('Mean values of each feature (Males)',fontsize=13, weight='bold')
ax1.text(200,0.8,'liver patient',fontsize=20,horizontalalignment='center', color='orange', weight='bold')

plt.sca(ax1)

# people with disease
ax2 = fig.add_subplot(212,sharex=ax1)
ax2.grid()
ax2.set_title('Mean values of each feature (Males)',fontsize=13,weight='bold')
ax2.text(200,0.8,'non liver patient',fontsize=20,horizontalalignment='center',color='green',weight='bold')

plt.sca(ax2)

# show plots
sns.barplot(data=data1,ax=ax1,orient='horizontal', palette='bright')
sns.barplot(data=data2,ax=ax2,orient='horizontal', palette='bright')

fig.savefig("./png_results/patient-vs-nonpatient-features-m.png", dpi=300)

# %% [markdown]
# As we can see above mean values of ALKPHOS, SGPT and SGOT tend to be much lower in liver patients than in non liver patients.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## change non-numerical values to integers

# %%
# transform Gender to numerical values
le = preprocessing.LabelEncoder()
le.fit(['Male','Female'])
df.loc[:,'Gender'] = le.transform(df['Gender'])

# %%
# transform selector from 1-2 to 0-1
df['selector'] = df['selector'].map({2:0, 1:1})

# display the result
df.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio  selector
# 0   65       0   0.7  0.1      187    16    18  6.8  3.3      0.90         1
# 1   62       1  10.9  5.5      699    64   100  7.5  3.2      0.74         1
# 2   62       1   7.3  4.1      490    60    68  7.0  3.3      0.89         1
# 3   58       1   1.0  0.4      182    14    20  6.8  3.4      1.00         1
# 4   72       1   3.9  2.0      195    27    59  7.3  2.4      0.40         1

# %% [markdown]
# ## remove empty values

# %%
# we can see that there are some null values in AG Ratio
df = df.dropna(how = 'any', axis = 0)

# check now
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 579 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       579 non-null    int64
#  1   Gender    579 non-null    int64
#  2   TB        579 non-null    float64
#  3   DB        579 non-null    float64
#  4   ALKPHOS   579 non-null    int64
#  5   SGPT      579 non-null    int64
#  6   SGOT      579 non-null    int64
#  7   TP        579 non-null    float64
#  8   ALB       579 non-null    float64
#  9   AG Ratio  579 non-null    float64
#  10  selector  579 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 54.3 KB

# %% [markdown]
# ## split data into features & classes

# %%
# split data into feture set X and labels y
y = df['selector']
X = df.drop('selector', axis=1)

# show first five cols of feature set
X.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio
# 0   65       0   0.7  0.1      187    16    18  6.8  3.3      0.90
# 1   62       1  10.9  5.5      699    64   100  7.5  3.2      0.74
# 2   62       1   7.3  4.1      490    60    68  7.0  3.3      0.89
# 3   58       1   1.0  0.4      182    14    20  6.8  3.4      1.00
# 4   72       1   3.9  2.0      195    27    59  7.3  2.4      0.40

# %% [markdown]
# ## feature selection

# %%
selected_X = SelectKBest(chi2, k=5).fit(X, y)
selected_X_df = pd.DataFrame({'Feature': list(X.columns),
                                    'Scores': selected_X.scores_})
selected_X_df.sort_values(by='Scores', ascending=False)
# Out:
#     Feature        Scores
# 6      SGOT  10138.860197
# 5      SGPT   6361.141943
# 4   ALKPHOS   3956.690967
# 2        TB    327.913058
# 3        DB    186.119776
# 0       Age     60.226677
# 8       ALB      2.966936
# 9  AG Ratio      1.658882
# 1    Gender      0.926483
# 7        TP      0.118535

# %% [markdown]
# ## display heatmap

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))
plt.title('Correlation of features')

# Draw the heatmap using seaborn
sns.heatmap(df.astype(float).corr(),linewidths=0.25,vmax=1.0, square=True, cmap="YlGnBu", linecolor='black',annot=True)

plt.savefig("./png_results/heatmap.png", dpi=300)

# %% [markdown]
# As we can see above:
# - DB & TB
# - SGOT & SGPT
# - ALB & TP
# - ALB & AG Ratio
#
# are highly correlated. Now we need to make a feature ranking to decide what features we want to use in classification.
#
# We can see that nothing correlates directly with selector - the highest correlation we can achieve with DB, but it's still only 0.25, but it's not a solid conclusion, because variables are biased (ex. most of people here are Males).

# %% [markdown]
# # Training & testing

# %%
def timestamp_ms():
    return int((datetime.datetime.utcnow() - datetime.datetime(1970, 1, 1)).total_seconds() * 1000)

# %%
def train_and_test(X, y, layer_size, solver, momentum=0.0):
    classifier = MLPClassifier(hidden_layer_sizes=(layer_size, ), solver=solver, activation='tanh', momentum=momentum, max_iter=10000)
    cross_validator = RepeatedStratifiedKFold(n_splits=2, n_repeats=5, random_state=1234)
    scores = []

    for train_index, test_index in cross_validator.split(X, y):
        # create training & testing set
        X_train, X_test = X[train_index, : ], X[test_index, : ]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # scale data
        scaler = MinMaxScaler()

        # fit to training data only & transform both
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        # fit & predict & calculate the score
        classifier.fit(X_train, y_train)
        predict = classifier.predict(X_test)
        acc_score = accuracy_score(y_test, predict)
        scores.append(acc_score)

    mean_score = np.mean(scores)
    std_score = np.std(scores)
    print("Accuracy score: %.3f (%.3f)" % (mean_score, std_score))
    return mean_score, std_score

# %%
min_features = 1
max_features = 11

layer_sizes = [2, 3, 5, 8, 10]
momentum_values = [0.0, 0.3, 0.1, 0.5, 0.9]

filename = 'results.csv'

with open(filename, 'w', newline='') as csvfile:
    fieldnames = ['features', 'layers', 'momentum', 'mean_score', 'std_score', 'time']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for k in range(min_features, max_features): 
        X_best = SelectKBest(chi2, k=k).fit_transform(X, y)

        for size in layer_sizes:
            for momentum in momentum_values:
                start = timestamp_ms()
                mean_score, std_score = train_and_test(X_best, y, size, 'sgd', momentum)
                stop = timestamp_ms()
                print("____features: {}, layers: {}, momentum: {}, time: {}____".format(k, size, momentum, stop-start))
                writer.writerow({'features': k, 'layers': size, 'momentum': momentum, 'mean_score': mean_score, 'std_score': std_score, 'time': stop-start})
        print("")
# Out:
# Accuracy score: 0.666 (0.129)
# ____features: 1, layers: 2, momentum: 0.0, time: 2479____
# Accuracy score: 0.714 (0.002)
# ____features: 1, layers: 2, momentum: 0.3, time: 1580____
# Accuracy score: 0.714 (0.003)
# ____features: 1, layers: 2, momentum: 0.1, time: 1512____
# Accuracy score: 0.713 (0.005)
# ____features: 1, layers: 2, momentum: 0.5, time: 1825____
# Accuracy score: 0.715 (0.002)
# ____features: 1, layers: 2, momentum: 0.9, time: 1336____
# Accuracy score: 0.663 (0.128)
# ____features: 1, layers: 3, momentum: 0.0, time: 3698____
# Accuracy score: 0.714 (0.002)
# ____features: 1, layers: 3, momentum: 0.3, time: 2821____
# Accuracy score: 0.714 (0.002)
# ____features: 1, layers: 3, momentum: 0.1, time: 2160____
# Accuracy score: 0.715 (0.002)
# ____features: 1, layers: 3, momentum: 0.5, time: 2889____
# Accuracy score: 0.714 (0.003)
# ____features: 1, layers: 3, momentum: 0.9, time: 1813____
# Accuracy score: 0.672 (0.129)
# ____features: 1, layers: 5, momentum: 0.0, time: 2188____
# Accuracy score: 0.712 (0.006)
# ____features: 1, layers: 5, momentum: 0.3, time: 1565____
# Accuracy score: 0.714 (0.004)
# ____features: 1, layers: 5, momentum: 0.1, time: 802____
# Accuracy score: 0.714 (0.003)
# ____features: 1, layers: 5, momentum: 0.5, time: 1409____
# Accuracy score: 0.714 (0.002)
# ____features: 1, layers: 5, momentum: 0.9, time: 782____
# Accuracy score: 0.714 (0.004)
# ____features: 1, layers: 8, momentum: 0.0, time: 1911____
# Accuracy score: 0.715 (0.002)
# ____features: 1, layers: 8, momentum: 0.3, time: 2220____
# Accuracy score: 0.714 (0.004)
# ____features: 1, layers: 8, momentum: 0.1, time: 2119____
# Accuracy score: 0.715 (0.002)
# ____features: 1, layers: 8, momentum: 0.5, time: 1525____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 8, momentum: 0.9, time: 768____
# Accuracy score: 0.713 (0.005)
# ____features: 1, layers: 10, momentum: 0.0, time: 2207____
# Accuracy score: 0.714 (0.002)
# ____features: 1, layers: 10, momentum: 0.3, time: 2521____
# Accuracy score: 0.709 (0.018)
# ____features: 1, layers: 10, momentum: 0.1, time: 2611____
# Accuracy score: 0.714 (0.003)
# ____features: 1, layers: 10, momentum: 0.5, time: 957____
# Accuracy score: 0.714 (0.002)
# ____features: 1, layers: 10, momentum: 0.9, time: 622____
#
# Accuracy score: 0.583 (0.195)
# ____features: 2, layers: 2, momentum: 0.0, time: 3855____
# Accuracy score: 0.708 (0.020)
# ____features: 2, layers: 2, momentum: 0.3, time: 3106____
# Accuracy score: 0.712 (0.006)
# ____features: 2, layers: 2, momentum: 0.1, time: 3649____
# Accuracy score: 0.714 (0.004)
# ____features: 2, layers: 2, momentum: 0.5, time: 1591____
# Accuracy score: 0.712 (0.006)
# ____features: 2, layers: 2, momentum: 0.9, time: 685____
# Accuracy score: 0.714 (0.003)
# ____features: 2, layers: 3, momentum: 0.0, time: 2158____
# Accuracy score: 0.715 (0.001)
# ____features: 2, layers: 3, momentum: 0.3, time: 1593____
# Accuracy score: 0.712 (0.009)
# ____features: 2, layers: 3, momentum: 0.1, time: 1430____
# Accuracy score: 0.712 (0.003)
# ____features: 2, layers: 3, momentum: 0.5, time: 2204____
# Accuracy score: 0.714 (0.002)
# ____features: 2, layers: 3, momentum: 0.9, time: 1077____
# Accuracy score: 0.713 (0.006)
# ____features: 2, layers: 5, momentum: 0.0, time: 2300____
# Accuracy score: 0.711 (0.007)
# ____features: 2, layers: 5, momentum: 0.3, time: 2413____
# Accuracy score: 0.714 (0.002)
# ____features: 2, layers: 5, momentum: 0.1, time: 1634____
# Accuracy score: 0.711 (0.010)
# ____features: 2, layers: 5, momentum: 0.5, time: 2466____
# Accuracy score: 0.714 (0.003)
# ____features: 2, layers: 5, momentum: 0.9, time: 962____
# Accuracy score: 0.714 (0.003)
# ____features: 2, layers: 8, momentum: 0.0, time: 2466____
# Accuracy score: 0.711 (0.010)
# ____features: 2, layers: 8, momentum: 0.3, time: 2681____
# Accuracy score: 0.713 (0.003)
# ____features: 2, layers: 8, momentum: 0.1, time: 1496____
# Accuracy score: 0.713 (0.007)
# ____features: 2, layers: 8, momentum: 0.5, time: 1552____
# Accuracy score: 0.714 (0.002)
# ____features: 2, layers: 8, momentum: 0.9, time: 976____
# Accuracy score: 0.713 (0.003)
# ____features: 2, layers: 10, momentum: 0.0, time: 2901____
# Accuracy score: 0.712 (0.005)
# ____features: 2, layers: 10, momentum: 0.3, time: 2415____
# Accuracy score: 0.712 (0.007)
# ____features: 2, layers: 10, momentum: 0.1, time: 2296____
# Accuracy score: 0.715 (0.001)
# ____features: 2, layers: 10, momentum: 0.5, time: 1927____
# Accuracy score: 0.715 (0.001)
# ____features: 2, layers: 10, momentum: 0.9, time: 878____
#
# Accuracy score: 0.670 (0.128)
# ____features: 3, layers: 2, momentum: 0.0, time: 2869____
# Accuracy score: 0.713 (0.004)
# ____features: 3, layers: 2, momentum: 0.3, time: 2589____
# Accuracy score: 0.715 (0.002)
# ____features: 3, layers: 2, momentum: 0.1, time: 1673____
# Accuracy score: 0.712 (0.004)
# ____features: 3, layers: 2, momentum: 0.5, time: 2063____
# Accuracy score: 0.714 (0.002)
# ____features: 3, layers: 2, momentum: 0.9, time: 697____
# Accuracy score: 0.697 (0.024)
# ____features: 3, layers: 3, momentum: 0.0, time: 3525____
# Accuracy score: 0.714 (0.003)
# ____features: 3, layers: 3, momentum: 0.3, time: 3455____
# Accuracy score: 0.711 (0.008)
# ____features: 3, layers: 3, momentum: 0.1, time: 5391____
# Accuracy score: 0.712 (0.004)
# ____features: 3, layers: 3, momentum: 0.5, time: 1303____
# Accuracy score: 0.715 (0.002)
# ____features: 3, layers: 3, momentum: 0.9, time: 1225____
# Accuracy score: 0.707 (0.017)
# ____features: 3, layers: 5, momentum: 0.0, time: 2329____
# Accuracy score: 0.714 (0.002)
# ____features: 3, layers: 5, momentum: 0.3, time: 2286____
# Accuracy score: 0.710 (0.009)
# ____features: 3, layers: 5, momentum: 0.1, time: 2383____
# Accuracy score: 0.714 (0.002)
# ____features: 3, layers: 5, momentum: 0.5, time: 2093____
# Accuracy score: 0.715 (0.001)
# ____features: 3, layers: 5, momentum: 0.9, time: 923____
# Accuracy score: 0.715 (0.001)
# ____features: 3, layers: 8, momentum: 0.0, time: 2151____
# Accuracy score: 0.709 (0.013)
# ____features: 3, layers: 8, momentum: 0.3, time: 1583____
# Accuracy score: 0.714 (0.002)
# ____features: 3, layers: 8, momentum: 0.1, time: 2194____
# Accuracy score: 0.712 (0.007)
# ____features: 3, layers: 8, momentum: 0.5, time: 1350____
# Accuracy score: 0.715 (0.002)
# ____features: 3, layers: 8, momentum: 0.9, time: 521____
# Accuracy score: 0.704 (0.017)
# ____features: 3, layers: 10, momentum: 0.0, time: 1383____
# Accuracy score: 0.710 (0.015)
# ____features: 3, layers: 10, momentum: 0.3, time: 2255____
# Accuracy score: 0.711 (0.007)
# ____features: 3, layers: 10, momentum: 0.1, time: 2060____
# Accuracy score: 0.714 (0.003)
# ____features: 3, layers: 10, momentum: 0.5, time: 1764____
# Accuracy score: 0.715 (0.001)
# ____features: 3, layers: 10, momentum: 0.9, time: 549____
#
# Accuracy score: 0.662 (0.127)
# ____features: 4, layers: 2, momentum: 0.0, time: 2507____
# Accuracy score: 0.713 (0.006)
# ____features: 4, layers: 2, momentum: 0.3, time: 1493____
# Accuracy score: 0.706 (0.020)
# ____features: 4, layers: 2, momentum: 0.1, time: 1026____
# Accuracy score: 0.713 (0.006)
# ____features: 4, layers: 2, momentum: 0.5, time: 1918____
# Accuracy score: 0.715 (0.001)
# ____features: 4, layers: 2, momentum: 0.9, time: 1125____
# Accuracy score: 0.707 (0.014)
# ____features: 4, layers: 3, momentum: 0.0, time: 1620____
# Accuracy score: 0.709 (0.011)
# ____features: 4, layers: 3, momentum: 0.3, time: 1489____
# Accuracy score: 0.705 (0.014)
# ____features: 4, layers: 3, momentum: 0.1, time: 2461____
# Accuracy score: 0.714 (0.003)
# ____features: 4, layers: 3, momentum: 0.5, time: 1346____
# Accuracy score: 0.714 (0.003)
# ____features: 4, layers: 3, momentum: 0.9, time: 873____
# Accuracy score: 0.711 (0.009)
# ____features: 4, layers: 5, momentum: 0.0, time: 3357____
# Accuracy score: 0.706 (0.015)
# ____features: 4, layers: 5, momentum: 0.3, time: 3521____
# Accuracy score: 0.707 (0.010)
# ____features: 4, layers: 5, momentum: 0.1, time: 2648____
# Accuracy score: 0.712 (0.004)
# ____features: 4, layers: 5, momentum: 0.5, time: 2951____
# Accuracy score: 0.715 (0.001)
# ____features: 4, layers: 5, momentum: 0.9, time: 1034____
# Accuracy score: 0.713 (0.004)
# ____features: 4, layers: 8, momentum: 0.0, time: 1621____
# Accuracy score: 0.715 (0.002)
# ____features: 4, layers: 8, momentum: 0.3, time: 2154____
# Accuracy score: 0.711 (0.007)
# ____features: 4, layers: 8, momentum: 0.1, time: 1803____
# Accuracy score: 0.712 (0.005)
# ____features: 4, layers: 8, momentum: 0.5, time: 1320____
# Accuracy score: 0.715 (0.001)
# ____features: 4, layers: 8, momentum: 0.9, time: 616____
# Accuracy score: 0.711 (0.005)
# ____features: 4, layers: 10, momentum: 0.0, time: 2403____
# Accuracy score: 0.712 (0.004)
# ____features: 4, layers: 10, momentum: 0.3, time: 2330____
# Accuracy score: 0.706 (0.020)
# ____features: 4, layers: 10, momentum: 0.1, time: 2521____
# Accuracy score: 0.714 (0.003)
# ____features: 4, layers: 10, momentum: 0.5, time: 2065____
# Accuracy score: 0.715 (0.001)
# ____features: 4, layers: 10, momentum: 0.9, time: 731____
#
# Accuracy score: 0.662 (0.127)
# ____features: 5, layers: 2, momentum: 0.0, time: 2761____
# Accuracy score: 0.710 (0.011)
# ____features: 5, layers: 2, momentum: 0.3, time: 2232____
# Accuracy score: 0.699 (0.026)
# ____features: 5, layers: 2, momentum: 0.1, time: 2497____
# Accuracy score: 0.713 (0.004)
# ____features: 5, layers: 2, momentum: 0.5, time: 2752____
# Accuracy score: 0.715 (0.001)
# ____features: 5, layers: 2, momentum: 0.9, time: 842____
# Accuracy score: 0.701 (0.025)
# ____features: 5, layers: 3, momentum: 0.0, time: 2759____
# Accuracy score: 0.706 (0.016)
# ____features: 5, layers: 3, momentum: 0.3, time: 2357____
# Accuracy score: 0.708 (0.015)
# ____features: 5, layers: 3, momentum: 0.1, time: 1940____
# Accuracy score: 0.706 (0.017)
# ____features: 5, layers: 3, momentum: 0.5, time: 1054____
# Accuracy score: 0.714 (0.002)
# ____features: 5, layers: 3, momentum: 0.9, time: 998____
# Accuracy score: 0.697 (0.037)
# ____features: 5, layers: 5, momentum: 0.0, time: 2313____
# Accuracy score: 0.715 (0.002)
# ____features: 5, layers: 5, momentum: 0.3, time: 1450____
# Accuracy score: 0.703 (0.028)
# ____features: 5, layers: 5, momentum: 0.1, time: 4624____
# Accuracy score: 0.701 (0.020)
# ____features: 5, layers: 5, momentum: 0.5, time: 1152____
# Accuracy score: 0.715 (0.001)
# ____features: 5, layers: 5, momentum: 0.9, time: 1033____
# Accuracy score: 0.705 (0.024)
# ____features: 5, layers: 8, momentum: 0.0, time: 2489____
# Accuracy score: 0.715 (0.001)
# ____features: 5, layers: 8, momentum: 0.3, time: 1780____
# Accuracy score: 0.711 (0.006)
# ____features: 5, layers: 8, momentum: 0.1, time: 2145____
# Accuracy score: 0.711 (0.008)
# ____features: 5, layers: 8, momentum: 0.5, time: 3254____
# Accuracy score: 0.714 (0.004)
# ____features: 5, layers: 8, momentum: 0.9, time: 942____
# Accuracy score: 0.712 (0.005)
# ____features: 5, layers: 10, momentum: 0.0, time: 2559____
# Accuracy score: 0.712 (0.005)
# ____features: 5, layers: 10, momentum: 0.3, time: 2356____
# Accuracy score: 0.711 (0.008)
# ____features: 5, layers: 10, momentum: 0.1, time: 1933____
# Accuracy score: 0.715 (0.001)
# ____features: 5, layers: 10, momentum: 0.5, time: 1950____
# Accuracy score: 0.715 (0.001)
# ____features: 5, layers: 10, momentum: 0.9, time: 925____
#
# Accuracy score: 0.538 (0.208)
# ____features: 6, layers: 2, momentum: 0.0, time: 2475____
# Accuracy score: 0.712 (0.006)
# ____features: 6, layers: 2, momentum: 0.3, time: 2438____
# Accuracy score: 0.712 (0.010)
# ____features: 6, layers: 2, momentum: 0.1, time: 4583____
# Accuracy score: 0.711 (0.008)
# ____features: 6, layers: 2, momentum: 0.5, time: 2545____
# Accuracy score: 0.714 (0.004)
# ____features: 6, layers: 2, momentum: 0.9, time: 1089____
# Accuracy score: 0.664 (0.128)
# ____features: 6, layers: 3, momentum: 0.0, time: 1082____
# Accuracy score: 0.705 (0.013)
# ____features: 6, layers: 3, momentum: 0.3, time: 2609____
# Accuracy score: 0.700 (0.022)
# ____features: 6, layers: 3, momentum: 0.1, time: 3030____
# Accuracy score: 0.707 (0.013)
# ____features: 6, layers: 3, momentum: 0.5, time: 1576____
# Accuracy score: 0.714 (0.003)
# ____features: 6, layers: 3, momentum: 0.9, time: 893____
# Accuracy score: 0.703 (0.020)
# ____features: 6, layers: 5, momentum: 0.0, time: 3457____
# Accuracy score: 0.712 (0.009)
# ____features: 6, layers: 5, momentum: 0.3, time: 899____
# Accuracy score: 0.708 (0.020)
# ____features: 6, layers: 5, momentum: 0.1, time: 3387____
# Accuracy score: 0.706 (0.020)
# ____features: 6, layers: 5, momentum: 0.5, time: 1362____
# Accuracy score: 0.714 (0.002)
# ____features: 6, layers: 5, momentum: 0.9, time: 1137____
# Accuracy score: 0.709 (0.011)
# ____features: 6, layers: 8, momentum: 0.0, time: 2541____
# Accuracy score: 0.709 (0.011)
# ____features: 6, layers: 8, momentum: 0.3, time: 3088____
# Accuracy score: 0.709 (0.013)
# ____features: 6, layers: 8, momentum: 0.1, time: 2571____
# Accuracy score: 0.714 (0.004)
# ____features: 6, layers: 8, momentum: 0.5, time: 2005____
# Accuracy score: 0.714 (0.003)
# ____features: 6, layers: 8, momentum: 0.9, time: 1078____
# Accuracy score: 0.710 (0.009)
# ____features: 6, layers: 10, momentum: 0.0, time: 2864____
# Accuracy score: 0.713 (0.006)
# ____features: 6, layers: 10, momentum: 0.3, time: 2867____
# Accuracy score: 0.706 (0.014)
# ____features: 6, layers: 10, momentum: 0.1, time: 2685____
# Accuracy score: 0.708 (0.014)
# ____features: 6, layers: 10, momentum: 0.5, time: 1823____
# Accuracy score: 0.715 (0.002)
# ____features: 6, layers: 10, momentum: 0.9, time: 648____
#
# Accuracy score: 0.650 (0.126)
# ____features: 7, layers: 2, momentum: 0.0, time: 4074____
# Accuracy score: 0.709 (0.018)
# ____features: 7, layers: 2, momentum: 0.3, time: 1607____
# Accuracy score: 0.711 (0.009)
# ____features: 7, layers: 2, momentum: 0.1, time: 1264____
# Accuracy score: 0.696 (0.027)
# ____features: 7, layers: 2, momentum: 0.5, time: 2591____
# Accuracy score: 0.715 (0.001)
# ____features: 7, layers: 2, momentum: 0.9, time: 1345____
# Accuracy score: 0.695 (0.034)
# ____features: 7, layers: 3, momentum: 0.0, time: 1922____
# Accuracy score: 0.711 (0.010)
# ____features: 7, layers: 3, momentum: 0.3, time: 2209____
# Accuracy score: 0.698 (0.028)
# ____features: 7, layers: 3, momentum: 0.1, time: 3557____
# Accuracy score: 0.701 (0.028)
# ____features: 7, layers: 3, momentum: 0.5, time: 1856____
# Accuracy score: 0.715 (0.002)
# ____features: 7, layers: 3, momentum: 0.9, time: 1124____
# Accuracy score: 0.705 (0.014)
# ____features: 7, layers: 5, momentum: 0.0, time: 3070____
# Accuracy score: 0.714 (0.004)
# ____features: 7, layers: 5, momentum: 0.3, time: 3297____
# Accuracy score: 0.707 (0.014)
# ____features: 7, layers: 5, momentum: 0.1, time: 1824____
# Accuracy score: 0.708 (0.010)
# ____features: 7, layers: 5, momentum: 0.5, time: 1768____
# Accuracy score: 0.712 (0.008)
# ____features: 7, layers: 5, momentum: 0.9, time: 950____
# Accuracy score: 0.710 (0.010)
# ____features: 7, layers: 8, momentum: 0.0, time: 1070____
# Accuracy score: 0.713 (0.007)
# ____features: 7, layers: 8, momentum: 0.3, time: 1899____
# Accuracy score: 0.712 (0.004)
# ____features: 7, layers: 8, momentum: 0.1, time: 3050____
# Accuracy score: 0.713 (0.003)
# ____features: 7, layers: 8, momentum: 0.5, time: 1091____
# Accuracy score: 0.714 (0.003)
# ____features: 7, layers: 8, momentum: 0.9, time: 899____
# Accuracy score: 0.710 (0.008)
# ____features: 7, layers: 10, momentum: 0.0, time: 3254____
# Accuracy score: 0.714 (0.002)
# ____features: 7, layers: 10, momentum: 0.3, time: 2897____
# Accuracy score: 0.715 (0.001)
# ____features: 7, layers: 10, momentum: 0.1, time: 2703____
# Accuracy score: 0.711 (0.006)
# ____features: 7, layers: 10, momentum: 0.5, time: 2020____
# Accuracy score: 0.714 (0.004)
# ____features: 7, layers: 10, momentum: 0.9, time: 776____
#
# Accuracy score: 0.647 (0.126)
# ____features: 8, layers: 2, momentum: 0.0, time: 1962____
# Accuracy score: 0.710 (0.006)
# ____features: 8, layers: 2, momentum: 0.3, time: 2023____
# Accuracy score: 0.712 (0.009)
# ____features: 8, layers: 2, momentum: 0.1, time: 3450____
# Accuracy score: 0.711 (0.008)
# ____features: 8, layers: 2, momentum: 0.5, time: 2124____
# Accuracy score: 0.714 (0.003)
# ____features: 8, layers: 2, momentum: 0.9, time: 1097____
# Accuracy score: 0.693 (0.034)
# ____features: 8, layers: 3, momentum: 0.0, time: 2396____
# Accuracy score: 0.710 (0.010)
# ____features: 8, layers: 3, momentum: 0.3, time: 2881____
# Accuracy score: 0.696 (0.026)
# ____features: 8, layers: 3, momentum: 0.1, time: 2903____
# Accuracy score: 0.712 (0.005)
# ____features: 8, layers: 3, momentum: 0.5, time: 2645____
# Accuracy score: 0.714 (0.002)
# ____features: 8, layers: 3, momentum: 0.9, time: 733____
# Accuracy score: 0.708 (0.013)
# ____features: 8, layers: 5, momentum: 0.0, time: 2076____
# Accuracy score: 0.713 (0.002)
# ____features: 8, layers: 5, momentum: 0.3, time: 2197____
# Accuracy score: 0.710 (0.009)
# ____features: 8, layers: 5, momentum: 0.1, time: 2254____
# Accuracy score: 0.714 (0.003)
# ____features: 8, layers: 5, momentum: 0.5, time: 3138____
# Accuracy score: 0.715 (0.002)
# ____features: 8, layers: 5, momentum: 0.9, time: 891____
# Accuracy score: 0.706 (0.017)
# ____features: 8, layers: 8, momentum: 0.0, time: 2010____
# Accuracy score: 0.712 (0.006)
# ____features: 8, layers: 8, momentum: 0.3, time: 1811____
# Accuracy score: 0.710 (0.007)
# ____features: 8, layers: 8, momentum: 0.1, time: 3350____
# Accuracy score: 0.713 (0.004)
# ____features: 8, layers: 8, momentum: 0.5, time: 2537____
# Accuracy score: 0.714 (0.002)
# ____features: 8, layers: 8, momentum: 0.9, time: 1005____
# Accuracy score: 0.711 (0.011)
# ____features: 8, layers: 10, momentum: 0.0, time: 3340____
# Accuracy score: 0.708 (0.011)
# ____features: 8, layers: 10, momentum: 0.3, time: 1828____
# Accuracy score: 0.704 (0.023)
# ____features: 8, layers: 10, momentum: 0.1, time: 975____
# Accuracy score: 0.714 (0.004)
# ____features: 8, layers: 10, momentum: 0.5, time: 1735____
# Accuracy score: 0.715 (0.001)
# ____features: 8, layers: 10, momentum: 0.9, time: 837____
#
# Accuracy score: 0.622 (0.155)
# ____features: 9, layers: 2, momentum: 0.0, time: 1656____
# Accuracy score: 0.712 (0.006)
# ____features: 9, layers: 2, momentum: 0.3, time: 1796____
# Accuracy score: 0.695 (0.024)
# ____features: 9, layers: 2, momentum: 0.1, time: 3197____
# Accuracy score: 0.714 (0.003)
# ____features: 9, layers: 2, momentum: 0.5, time: 2546____
# Accuracy score: 0.714 (0.003)
# ____features: 9, layers: 2, momentum: 0.9, time: 715____
# Accuracy score: 0.694 (0.065)
# ____features: 9, layers: 3, momentum: 0.0, time: 597____
# Accuracy score: 0.693 (0.027)
# ____features: 9, layers: 3, momentum: 0.3, time: 2506____
# Accuracy score: 0.713 (0.004)
# ____features: 9, layers: 3, momentum: 0.1, time: 1598____
# Accuracy score: 0.709 (0.010)
# ____features: 9, layers: 3, momentum: 0.5, time: 2078____
# Accuracy score: 0.715 (0.002)
# ____features: 9, layers: 3, momentum: 0.9, time: 737____
# Accuracy score: 0.691 (0.027)
# ____features: 9, layers: 5, momentum: 0.0, time: 2495____
# Accuracy score: 0.699 (0.014)
# ____features: 9, layers: 5, momentum: 0.3, time: 3680____
# Accuracy score: 0.713 (0.004)
# ____features: 9, layers: 5, momentum: 0.1, time: 1463____
# Accuracy score: 0.714 (0.003)
# ____features: 9, layers: 5, momentum: 0.5, time: 1838____
# Accuracy score: 0.710 (0.011)
# ____features: 9, layers: 5, momentum: 0.9, time: 918____
# Accuracy score: 0.702 (0.018)
# ____features: 9, layers: 8, momentum: 0.0, time: 1817____
# Accuracy score: 0.713 (0.005)
# ____features: 9, layers: 8, momentum: 0.3, time: 1961____
# Accuracy score: 0.708 (0.012)
# ____features: 9, layers: 8, momentum: 0.1, time: 2083____
# Accuracy score: 0.713 (0.006)
# ____features: 9, layers: 8, momentum: 0.5, time: 2741____
# Accuracy score: 0.715 (0.001)
# ____features: 9, layers: 8, momentum: 0.9, time: 723____
# Accuracy score: 0.708 (0.020)
# ____features: 9, layers: 10, momentum: 0.0, time: 1415____
# Accuracy score: 0.711 (0.004)
# ____features: 9, layers: 10, momentum: 0.3, time: 2026____
# Accuracy score: 0.709 (0.011)
# ____features: 9, layers: 10, momentum: 0.1, time: 2228____
# Accuracy score: 0.705 (0.019)
# ____features: 9, layers: 10, momentum: 0.5, time: 1963____
# Accuracy score: 0.715 (0.001)
# ____features: 9, layers: 10, momentum: 0.9, time: 1122____
#
# Accuracy score: 0.579 (0.190)
# ____features: 10, layers: 2, momentum: 0.0, time: 6486____
# Accuracy score: 0.704 (0.013)
# ____features: 10, layers: 2, momentum: 0.3, time: 2091____
# Accuracy score: 0.704 (0.024)
# ____features: 10, layers: 2, momentum: 0.1, time: 5706____
# Accuracy score: 0.705 (0.020)
# ____features: 10, layers: 2, momentum: 0.5, time: 1565____
# Accuracy score: 0.711 (0.011)
# ____features: 10, layers: 2, momentum: 0.9, time: 1086____
# Accuracy score: 0.702 (0.024)
# ____features: 10, layers: 3, momentum: 0.0, time: 2619____
# Accuracy score: 0.704 (0.021)
# ____features: 10, layers: 3, momentum: 0.3, time: 2417____
# Accuracy score: 0.714 (0.002)
# ____features: 10, layers: 3, momentum: 0.1, time: 1956____
# Accuracy score: 0.713 (0.003)
# ____features: 10, layers: 3, momentum: 0.5, time: 2127____
# Accuracy score: 0.713 (0.005)
# ____features: 10, layers: 3, momentum: 0.9, time: 886____
# Accuracy score: 0.695 (0.027)
# ____features: 10, layers: 5, momentum: 0.0, time: 2563____
# Accuracy score: 0.712 (0.004)
# ____features: 10, layers: 5, momentum: 0.3, time: 1185____
# Accuracy score: 0.706 (0.028)
# ____features: 10, layers: 5, momentum: 0.1, time: 2028____
# Accuracy score: 0.712 (0.010)
# ____features: 10, layers: 5, momentum: 0.5, time: 1749____
# Accuracy score: 0.713 (0.005)
# ____features: 10, layers: 5, momentum: 0.9, time: 607____
# Accuracy score: 0.708 (0.011)
# ____features: 10, layers: 8, momentum: 0.0, time: 1730____
# Accuracy score: 0.708 (0.015)
# ____features: 10, layers: 8, momentum: 0.3, time: 1875____
# Accuracy score: 0.714 (0.006)
# ____features: 10, layers: 8, momentum: 0.1, time: 2273____
# Accuracy score: 0.709 (0.009)
# ____features: 10, layers: 8, momentum: 0.5, time: 2189____
# Accuracy score: 0.715 (0.002)
# ____features: 10, layers: 8, momentum: 0.9, time: 843____
# Accuracy score: 0.710 (0.011)
# ____features: 10, layers: 10, momentum: 0.0, time: 2468____
# Accuracy score: 0.706 (0.023)
# ____features: 10, layers: 10, momentum: 0.3, time: 1839____
# Accuracy score: 0.713 (0.004)
# ____features: 10, layers: 10, momentum: 0.1, time: 1946____
# Accuracy score: 0.710 (0.009)
# ____features: 10, layers: 10, momentum: 0.5, time: 1998____
# Accuracy score: 0.714 (0.003)
# ____features: 10, layers: 10, momentum: 0.9, time: 777____
