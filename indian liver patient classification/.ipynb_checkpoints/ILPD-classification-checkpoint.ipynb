# %%
import pandas as pd
import numpy as np
import collections

from sklearn import preprocessing
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, RobustScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_classif
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import RepeatedStratifiedKFold

import datetime


import seaborn as sns
import logging
import csv

import matplotlib
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [12, 8]

font = {'family' : 'normal',
        'size'   : 13}

matplotlib.rc('font', **font)

# %% [markdown]
# # About the data set

# %% [markdown]
# This data set contains 416 liver patient records and 167 non liver patient records.The data set was collected from north east of Andhra Pradesh, India. Selector is a class label used to divide into groups(liver patient or not). This data set contains 441 male patient records and 142 female patient records.
#
# Any patient whose age exceeded 89 is listed as being of age "90".
#
# ## Attributes
# 1. Age - Age of the patient
# 2. Gender - Gender of the patient
# 3. TB - Total Bilirubin
# 4. DB - Direct Bilirubin
# 5. Alkphos - Alkaline Phosphotase
# 6. Sgpt - Alamine Aminotransferase
# 7. Sgot - Aspartate Aminotransferase
# 8. TP - Total Protiens
# 9. ALB - Albumin
# 10. A/G Ratio - Albumin and Globulin Ratio
# 11. Selector field used to split the data into two sets (labeled by the experts)

# %% [markdown]
# # Read the data

# %%
# dataset location
dataset_location = "./dataset/ilpd_dataset.csv"

# column names
names = ['Age', 'Gender', 'TB', 'DB', 'ALKPHOS', 'SGPT', 'SGOT', 'TP', 'ALB', 'AG Ratio', 'selector']

# read dataset to pandas dataframe
df = pd.read_csv(dataset_location, names=names);

# %% [markdown]
# # Data analysis

# %%
# show first five cols of the dataset
print("Data shape: ", df.shape)
df.head()
# Out:
# Data shape:  (583, 11)
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio  selector
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3      0.90         1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2      0.74         1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3      0.89         1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4      1.00         1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4      0.40         1

# %%
# check for null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       583 non-null    int64
#  1   Gender    583 non-null    object
#  2   TB        583 non-null    float64
#  3   DB        583 non-null    float64
#  4   ALKPHOS   583 non-null    int64
#  5   SGPT      583 non-null    int64
#  6   SGOT      583 non-null    int64
#  7   TP        583 non-null    float64
#  8   ALB       583 non-null    float64
#  9   AG Ratio  579 non-null    float64
#  10  selector  583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %% [markdown]
# ## Histograms

# %%
df.hist(figsize=(14,11))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x108f74210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18e48a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18e85d10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a18ebc9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18efad10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18f329d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a18f6fe50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18fa7a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18fb0590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a18fe3f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a19059dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1908fa90>]],
#       dtype=object)
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Compare number of samples

# %%
# show number of examples in each class
numb_of_classes = pd.value_counts(df['selector'], sort = True).sort_index()
numb_of_classes.plot(kind = 'bar')
plt.title("Number of examples for each class")
plt.xlabel("Selector")
plt.ylabel("Number of sample")
plt.savefig("./png_results/compare-numb-of-samples.png", dpi=300)

# %%
# show number of examples of each gender
numb_of_classes = pd.value_counts(df['Gender'], sort = True).sort_index()
numb_of_classes.plot(kind = 'bar')
plt.title("Number of examples for each gender")
plt.xlabel("Gender")
plt.ylabel("Number of samples")
plt.savefig("./png_results/compare-genders.png", dpi=300)

# %% [markdown]
# ## Compare mean features of each category

# %%
data1 = df[df['selector'] == 2] # no disease
data1 = data1[data1['Gender'] == 'Female']
data1 = data1.iloc[:,:-1]

data2 = df[df['selector'] == 1] # disease
data2 = data2[data2['Gender'] == 'Female']
data2 = data2.iloc[:,:-1]

fig = plt.figure(figsize=(10,15))

# people without disease
ax1 = fig.add_subplot(211)
ax1.grid()
ax1.set_title('Mean values of each feature (Females)',fontsize=13, weight='bold')
ax1.text(200,0.8,'liver patient',fontsize=20,horizontalalignment='center', color='orange', weight='bold')

plt.sca(ax1)

# people with disease
ax2 = fig.add_subplot(212,sharex=ax1)
ax2.grid()
ax2.set_title('Mean values of each feature (Female)',fontsize=13,weight='bold')
ax2.text(200,0.8,'non liver patient',fontsize=20,horizontalalignment='center',color='green',weight='bold')

plt.sca(ax2)

# show plots
sns.barplot(data=data1,ax=ax1,orient='horizontal', palette='bright')
sns.barplot(data=data2,ax=ax2,orient='horizontal', palette='bright')

fig.savefig("./png_results/patient-vs-nonpatient-features.png", dpi=300)
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
data1 = df[df['selector'] == 2] # no disease
data1 = data1[data1['Gender'] == 'Male']
data1 = data1.iloc[:,:-1]

data2 = df[df['selector'] == 1] # disease
data2 = data2[data2['Gender'] == 'Male']
data2 = data2.iloc[:,:-1]

fig = plt.figure(figsize=(10,15))

# people without disease
ax1 = fig.add_subplot(211)
ax1.grid()
ax1.set_title('Mean values of each feature (Males)',fontsize=13, weight='bold')
ax1.text(200,0.8,'liver patient',fontsize=20,horizontalalignment='center', color='orange', weight='bold')

plt.sca(ax1)

# people with disease
ax2 = fig.add_subplot(212,sharex=ax1)
ax2.grid()
ax2.set_title('Mean values of each feature (Males)',fontsize=13,weight='bold')
ax2.text(200,0.8,'non liver patient',fontsize=20,horizontalalignment='center',color='green',weight='bold')

plt.sca(ax2)

# show plots
sns.barplot(data=data1,ax=ax1,orient='horizontal', palette='bright')
sns.barplot(data=data2,ax=ax2,orient='horizontal', palette='bright')

fig.savefig("./png_results/patient-vs-nonpatient-features-m.png", dpi=300)

# %% [markdown]
# As we can see above mean values of ALKPHOS, SGPT and SGOT tend to be much lower in liver patients than in non liver patients.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## change non-numerical values to integers

# %%
# transform Gender to numerical values
le = preprocessing.LabelEncoder()
le.fit(['Male','Female'])
df.loc[:,'Gender'] = le.transform(df['Gender'])

# %%
# transform selector from 1-2 to 0-1
df['selector'] = df['selector'].map({2:0, 1:1})

# display the result
df.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio  selector
# 0   65       0   0.7  0.1      187    16    18  6.8  3.3      0.90         1
# 1   62       1  10.9  5.5      699    64   100  7.5  3.2      0.74         1
# 2   62       1   7.3  4.1      490    60    68  7.0  3.3      0.89         1
# 3   58       1   1.0  0.4      182    14    20  6.8  3.4      1.00         1
# 4   72       1   3.9  2.0      195    27    59  7.3  2.4      0.40         1

# %% [markdown]
# ## remove empty values

# %%
# we can see that there are some null values in AG Ratio
df = df.dropna(how = 'any', axis = 0)

# check now
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 579 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       579 non-null    int64
#  1   Gender    579 non-null    int64
#  2   TB        579 non-null    float64
#  3   DB        579 non-null    float64
#  4   ALKPHOS   579 non-null    int64
#  5   SGPT      579 non-null    int64
#  6   SGOT      579 non-null    int64
#  7   TP        579 non-null    float64
#  8   ALB       579 non-null    float64
#  9   AG Ratio  579 non-null    float64
#  10  selector  579 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 54.3 KB

# %% [markdown]
# ## split data into features & classes

# %%
# split data into feture set X and labels y
y = df['selector']
X = df.drop('selector', axis=1)

# show first five cols of feature set
X.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio
# 0   65       0   0.7  0.1      187    16    18  6.8  3.3      0.90
# 1   62       1  10.9  5.5      699    64   100  7.5  3.2      0.74
# 2   62       1   7.3  4.1      490    60    68  7.0  3.3      0.89
# 3   58       1   1.0  0.4      182    14    20  6.8  3.4      1.00
# 4   72       1   3.9  2.0      195    27    59  7.3  2.4      0.40

# %% [markdown]
# ## feature selection

# %%
selected_X = SelectKBest(chi2, k=5).fit(X, y)
selected_X_df = pd.DataFrame({'Feature': list(X.columns),
                                    'Scores': selected_X.scores_})
selected_X_df.sort_values(by='Scores', ascending=False)
# Out:
#     Feature        Scores
# 6      SGOT  10138.860197
# 5      SGPT   6361.141943
# 4   ALKPHOS   3956.690967
# 2        TB    327.913058
# 3        DB    186.119776
# 0       Age     60.226677
# 8       ALB      2.966936
# 9  AG Ratio      1.658882
# 1    Gender      0.926483
# 7        TP      0.118535

# %% [markdown]
# ## display heatmap

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))
plt.title('Correlation of features')

# Draw the heatmap using seaborn
sns.heatmap(df.astype(float).corr(),linewidths=0.25,vmax=1.0, square=True, cmap="YlGnBu", linecolor='black',annot=True)

plt.savefig("./png_results/heatmap.png", dpi=300)

# %% [markdown]
# As we can see above:
# - DB & TB
# - SGOT & SGPT
# - ALB & TP
# - ALB & AG Ratio
#
# are highly correlated. Now we need to make a feature ranking to decide what features we want to use in classification.
#
# We can see that nothing correlates directly with selector - the highest correlation we can achieve with DB, but it's still only 0.25, but it's not a solid conclusion, because variables are biased (ex. most of people here are Males).

# %% [markdown]
# # Training & testing

# %%
def timestamp_ms():
    return int((datetime.datetime.utcnow() - datetime.datetime(1970, 1, 1)).total_seconds() * 1000)

# %%
def train_and_test(X, y, layer_size, solver, momentum=0.0):
    classifier = MLPClassifier(hidden_layer_sizes=(layer_size, ), solver=solver, momentum=momentum, max_iter=10000)
    cross_validator = RepeatedStratifiedKFold(n_splits=2, n_repeats=5, random_state=1234)
    scores = []

    for train_index, test_index in cross_validator.split(X, y):
        # create training & testing set
        X_train, X_test = X[train_index, : ], X[test_index, : ]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # scale data
        scaler = MinMaxScaler()

        # fit to training data only & transform both
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        # fit & predict & calculate the score
        classifier.fit(X_train, y_train)
        predict = classifier.predict(X_test)
        acc_score = accuracy_score(y_test, predict)
        scores.append(acc_score)

    mean_score = np.mean(scores)
    std_score = np.std(scores)
    print("Accuracy score: %.3f (%.3f)" % (mean_score, std_score))
    return mean_score, std_score

# %%
min_features = 1
max_features = 11

layer_sizes = [2, 3, 5, 8, 10]
momentum_values = [0.0, 0.3, 0.1, 0.5, 0.9]

filename = 'results.csv'

with open(filename, 'w', newline='') as csvfile:
    fieldnames = ['features', 'layers', 'momentum', 'mean_score', 'std_score', 'time']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for k in range(min_features, max_features): 
        X_best = SelectKBest(chi2, k=k).fit_transform(X, y)

        for size in layer_sizes:
            for momentum in momentum_values:
                start = timestamp_ms()
                mean_score, std_score = train_and_test(X_best, y, size, 'sgd', momentum)
                stop = timestamp_ms()
                print("____features: {}, layers: {}, momentum: {}, time: {}____".format(k, size, momentum, stop-start))
                writer.writerow({'features': k, 'layers': size, 'momentum': momentum, 'mean_score': mean_score, 'std_score': std_score, 'time': stop-start})
        print("")
# Out:
# Accuracy score: 0.626 (0.171)
# ____features: 1, layers: 2, momentum: 0.0, time: 3287____
# Accuracy score: 0.715 (0.002)
# ____features: 1, layers: 2, momentum: 0.3, time: 1993____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 2, momentum: 0.1, time: 1394____
# Accuracy score: 0.714 (0.003)
# ____features: 1, layers: 2, momentum: 0.5, time: 1822____
# Accuracy score: 0.714 (0.004)
# ____features: 1, layers: 2, momentum: 0.9, time: 780____
# Accuracy score: 0.668 (0.129)
# ____features: 1, layers: 3, momentum: 0.0, time: 2205____
# Accuracy score: 0.714 (0.002)
# ____features: 1, layers: 3, momentum: 0.3, time: 1598____
# Accuracy score: 0.714 (0.003)
# ____features: 1, layers: 3, momentum: 0.1, time: 1755____
# Accuracy score: 0.712 (0.010)
# ____features: 1, layers: 3, momentum: 0.5, time: 2054____
# Accuracy score: 0.714 (0.004)
# ____features: 1, layers: 3, momentum: 0.9, time: 1115____
# Accuracy score: 0.712 (0.006)
# ____features: 1, layers: 5, momentum: 0.0, time: 2588____
# Accuracy score: 0.713 (0.005)
# ____features: 1, layers: 5, momentum: 0.3, time: 2906____
# Accuracy score: 0.715 (0.002)
# ____features: 1, layers: 5, momentum: 0.1, time: 1693____
# Accuracy score: 0.714 (0.003)
# ____features: 1, layers: 5, momentum: 0.5, time: 1563____
# Accuracy score: 0.714 (0.003)
# ____features: 1, layers: 5, momentum: 0.9, time: 1197____
# Accuracy score: 0.714 (0.002)
# ____features: 1, layers: 8, momentum: 0.0, time: 1193____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 8, momentum: 0.3, time: 1012____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 8, momentum: 0.1, time: 1290____
# Accuracy score: 0.714 (0.003)
# ____features: 1, layers: 8, momentum: 0.5, time: 1044____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 8, momentum: 0.9, time: 883____
# Accuracy score: 0.711 (0.013)
# ____features: 1, layers: 10, momentum: 0.0, time: 2230____
# Accuracy score: 0.714 (0.002)
# ____features: 1, layers: 10, momentum: 0.3, time: 2370____
# Accuracy score: 0.714 (0.003)
# ____features: 1, layers: 10, momentum: 0.1, time: 2811____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 10, momentum: 0.5, time: 1962____
# Accuracy score: 0.715 (0.002)
# ____features: 1, layers: 10, momentum: 0.9, time: 660____
#
# Accuracy score: 0.579 (0.186)
# ____features: 2, layers: 2, momentum: 0.0, time: 1903____
# Accuracy score: 0.709 (0.010)
# ____features: 2, layers: 2, momentum: 0.3, time: 3293____
# Accuracy score: 0.714 (0.003)
# ____features: 2, layers: 2, momentum: 0.1, time: 1612____
# Accuracy score: 0.714 (0.003)
# ____features: 2, layers: 2, momentum: 0.5, time: 1909____
# Accuracy score: 0.713 (0.004)
# ____features: 2, layers: 2, momentum: 0.9, time: 857____
# Accuracy score: 0.706 (0.019)
# ____features: 2, layers: 3, momentum: 0.0, time: 1397____
# Accuracy score: 0.713 (0.005)
# ____features: 2, layers: 3, momentum: 0.3, time: 2519____
# Accuracy score: 0.711 (0.006)
# ____features: 2, layers: 3, momentum: 0.1, time: 2935____
# Accuracy score: 0.711 (0.013)
# ____features: 2, layers: 3, momentum: 0.5, time: 3329____
# Accuracy score: 0.715 (0.002)
# ____features: 2, layers: 3, momentum: 0.9, time: 1016____
# Accuracy score: 0.714 (0.002)
# ____features: 2, layers: 5, momentum: 0.0, time: 1031____
# Accuracy score: 0.707 (0.016)
# ____features: 2, layers: 5, momentum: 0.3, time: 1584____
# Accuracy score: 0.713 (0.004)
# ____features: 2, layers: 5, momentum: 0.1, time: 2177____
# Accuracy score: 0.713 (0.004)
# ____features: 2, layers: 5, momentum: 0.5, time: 2195____
# Accuracy score: 0.714 (0.003)
# ____features: 2, layers: 5, momentum: 0.9, time: 603____
# Accuracy score: 0.704 (0.019)
# ____features: 2, layers: 8, momentum: 0.0, time: 2717____
# Accuracy score: 0.715 (0.001)
# ____features: 2, layers: 8, momentum: 0.3, time: 1668____
# Accuracy score: 0.707 (0.013)
# ____features: 2, layers: 8, momentum: 0.1, time: 1379____
# Accuracy score: 0.713 (0.004)
# ____features: 2, layers: 8, momentum: 0.5, time: 1545____
# Accuracy score: 0.715 (0.001)
# ____features: 2, layers: 8, momentum: 0.9, time: 649____
# Accuracy score: 0.714 (0.002)
# ____features: 2, layers: 10, momentum: 0.0, time: 1649____
# Accuracy score: 0.714 (0.002)
# ____features: 2, layers: 10, momentum: 0.3, time: 2613____
# Accuracy score: 0.712 (0.006)
# ____features: 2, layers: 10, momentum: 0.1, time: 2064____
# Accuracy score: 0.713 (0.004)
# ____features: 2, layers: 10, momentum: 0.5, time: 1726____
# Accuracy score: 0.715 (0.001)
# ____features: 2, layers: 10, momentum: 0.9, time: 827____
#
# Accuracy score: 0.668 (0.125)
# ____features: 3, layers: 2, momentum: 0.0, time: 2248____
# Accuracy score: 0.710 (0.009)
# ____features: 3, layers: 2, momentum: 0.3, time: 2846____
# Accuracy score: 0.715 (0.001)
# ____features: 3, layers: 2, momentum: 0.1, time: 588____
# Accuracy score: 0.709 (0.014)
# ____features: 3, layers: 2, momentum: 0.5, time: 2357____
# Accuracy score: 0.714 (0.004)
# ____features: 3, layers: 2, momentum: 0.9, time: 982____
# Accuracy score: 0.667 (0.126)
# ____features: 3, layers: 3, momentum: 0.0, time: 2270____
# Accuracy score: 0.706 (0.013)
# ____features: 3, layers: 3, momentum: 0.3, time: 1577____
# Accuracy score: 0.707 (0.018)
# ____features: 3, layers: 3, momentum: 0.1, time: 2703____
# Accuracy score: 0.713 (0.005)
# ____features: 3, layers: 3, momentum: 0.5, time: 2666____
# Accuracy score: 0.714 (0.003)
# ____features: 3, layers: 3, momentum: 0.9, time: 765____
# Accuracy score: 0.665 (0.127)
# ____features: 3, layers: 5, momentum: 0.0, time: 1996____
# Accuracy score: 0.711 (0.007)
# ____features: 3, layers: 5, momentum: 0.3, time: 1889____
# Accuracy score: 0.710 (0.010)
# ____features: 3, layers: 5, momentum: 0.1, time: 2135____
# Accuracy score: 0.715 (0.001)
# ____features: 3, layers: 5, momentum: 0.5, time: 1149____
# Accuracy score: 0.715 (0.002)
# ____features: 3, layers: 5, momentum: 0.9, time: 582____
# Accuracy score: 0.672 (0.126)
# ____features: 3, layers: 8, momentum: 0.0, time: 1996____
# Accuracy score: 0.712 (0.005)
# ____features: 3, layers: 8, momentum: 0.3, time: 2289____
# Accuracy score: 0.710 (0.008)
# ____features: 3, layers: 8, momentum: 0.1, time: 3284____
# Accuracy score: 0.713 (0.005)
# ____features: 3, layers: 8, momentum: 0.5, time: 2324____
# Accuracy score: 0.715 (0.001)
# ____features: 3, layers: 8, momentum: 0.9, time: 836____
# Accuracy score: 0.713 (0.005)
# ____features: 3, layers: 10, momentum: 0.0, time: 1695____
# Accuracy score: 0.714 (0.005)
# ____features: 3, layers: 10, momentum: 0.3, time: 1520____
# Accuracy score: 0.714 (0.002)
# ____features: 3, layers: 10, momentum: 0.1, time: 2411____
# Accuracy score: 0.711 (0.008)
# ____features: 3, layers: 10, momentum: 0.5, time: 1777____
# Accuracy score: 0.713 (0.005)
# ____features: 3, layers: 10, momentum: 0.9, time: 1036____
#
# Accuracy score: 0.590 (0.191)
# ____features: 4, layers: 2, momentum: 0.0, time: 4253____
# Accuracy score: 0.707 (0.015)
# ____features: 4, layers: 2, momentum: 0.3, time: 3046____
# Accuracy score: 0.703 (0.024)
# ____features: 4, layers: 2, momentum: 0.1, time: 3683____
# Accuracy score: 0.714 (0.002)
# ____features: 4, layers: 2, momentum: 0.5, time: 1663____
# Accuracy score: 0.715 (0.001)
# ____features: 4, layers: 2, momentum: 0.9, time: 1020____
# Accuracy score: 0.650 (0.127)
# ____features: 4, layers: 3, momentum: 0.0, time: 3206____
# Accuracy score: 0.709 (0.016)
# ____features: 4, layers: 3, momentum: 0.3, time: 3067____
# Accuracy score: 0.714 (0.002)
# ____features: 4, layers: 3, momentum: 0.1, time: 1821____
# Accuracy score: 0.714 (0.003)
# ____features: 4, layers: 3, momentum: 0.5, time: 2130____
# Accuracy score: 0.713 (0.005)
# ____features: 4, layers: 3, momentum: 0.9, time: 1095____
# Accuracy score: 0.704 (0.021)
# ____features: 4, layers: 5, momentum: 0.0, time: 2620____
# Accuracy score: 0.705 (0.019)
# ____features: 4, layers: 5, momentum: 0.3, time: 2556____
# Accuracy score: 0.705 (0.023)
# ____features: 4, layers: 5, momentum: 0.1, time: 1837____
# Accuracy score: 0.708 (0.015)
# ____features: 4, layers: 5, momentum: 0.5, time: 1328____
# Accuracy score: 0.714 (0.004)
# ____features: 4, layers: 5, momentum: 0.9, time: 828____
# Accuracy score: 0.705 (0.020)
# ____features: 4, layers: 8, momentum: 0.0, time: 2176____
# Accuracy score: 0.713 (0.004)
# ____features: 4, layers: 8, momentum: 0.3, time: 3444____
# Accuracy score: 0.706 (0.010)
# ____features: 4, layers: 8, momentum: 0.1, time: 1635____
# Accuracy score: 0.712 (0.008)
# ____features: 4, layers: 8, momentum: 0.5, time: 1422____
# Accuracy score: 0.714 (0.004)
# ____features: 4, layers: 8, momentum: 0.9, time: 685____
# Accuracy score: 0.712 (0.006)
# ____features: 4, layers: 10, momentum: 0.0, time: 2384____
# Accuracy score: 0.713 (0.007)
# ____features: 4, layers: 10, momentum: 0.3, time: 1385____
# Accuracy score: 0.713 (0.003)
# ____features: 4, layers: 10, momentum: 0.1, time: 2631____
# Accuracy score: 0.714 (0.003)
# ____features: 4, layers: 10, momentum: 0.5, time: 1648____
# Accuracy score: 0.712 (0.007)
# ____features: 4, layers: 10, momentum: 0.9, time: 672____
#
# Accuracy score: 0.699 (0.037)
# ____features: 5, layers: 2, momentum: 0.0, time: 2173____
# Accuracy score: 0.712 (0.010)
# ____features: 5, layers: 2, momentum: 0.3, time: 1756____
# Accuracy score: 0.707 (0.022)
# ____features: 5, layers: 2, momentum: 0.1, time: 2594____
# Accuracy score: 0.707 (0.017)
# ____features: 5, layers: 2, momentum: 0.5, time: 2073____
# Accuracy score: 0.715 (0.002)
# ____features: 5, layers: 2, momentum: 0.9, time: 864____
# Accuracy score: 0.667 (0.108)
# ____features: 5, layers: 3, momentum: 0.0, time: 2111____
# Accuracy score: 0.698 (0.023)
# ____features: 5, layers: 3, momentum: 0.3, time: 2767____
# Accuracy score: 0.697 (0.029)
# ____features: 5, layers: 3, momentum: 0.1, time: 5342____
# Accuracy score: 0.712 (0.005)
# ____features: 5, layers: 3, momentum: 0.5, time: 1567____
# Accuracy score: 0.715 (0.001)
# ____features: 5, layers: 3, momentum: 0.9, time: 1433____
# Accuracy score: 0.706 (0.017)
# ____features: 5, layers: 5, momentum: 0.0, time: 2815____
# Accuracy score: 0.704 (0.020)
# ____features: 5, layers: 5, momentum: 0.3, time: 2071____
# Accuracy score: 0.708 (0.013)
# ____features: 5, layers: 5, momentum: 0.1, time: 3082____
# Accuracy score: 0.713 (0.004)
# ____features: 5, layers: 5, momentum: 0.5, time: 2354____
# Accuracy score: 0.712 (0.007)
# ____features: 5, layers: 5, momentum: 0.9, time: 1607____
# Accuracy score: 0.708 (0.013)
# ____features: 5, layers: 8, momentum: 0.0, time: 3243____
# Accuracy score: 0.712 (0.006)
# ____features: 5, layers: 8, momentum: 0.3, time: 1375____
# Accuracy score: 0.711 (0.005)
# ____features: 5, layers: 8, momentum: 0.1, time: 2681____
# Accuracy score: 0.711 (0.010)
# ____features: 5, layers: 8, momentum: 0.5, time: 1487____
# Accuracy score: 0.714 (0.004)
# ____features: 5, layers: 8, momentum: 0.9, time: 680____
# Accuracy score: 0.711 (0.006)
# ____features: 5, layers: 10, momentum: 0.0, time: 2019____
# Accuracy score: 0.712 (0.004)
# ____features: 5, layers: 10, momentum: 0.3, time: 2321____
# Accuracy score: 0.706 (0.017)
# ____features: 5, layers: 10, momentum: 0.1, time: 1728____
# Accuracy score: 0.712 (0.005)
# ____features: 5, layers: 10, momentum: 0.5, time: 1776____
# Accuracy score: 0.714 (0.002)
# ____features: 5, layers: 10, momentum: 0.9, time: 695____
#
# Accuracy score: 0.581 (0.194)
# ____features: 6, layers: 2, momentum: 0.0, time: 2539____
# Accuracy score: 0.710 (0.011)
# ____features: 6, layers: 2, momentum: 0.3, time: 2993____
# Accuracy score: 0.709 (0.013)
# ____features: 6, layers: 2, momentum: 0.1, time: 3544____
# Accuracy score: 0.715 (0.002)
# ____features: 6, layers: 2, momentum: 0.5, time: 2854____
# Accuracy score: 0.711 (0.014)
# ____features: 6, layers: 2, momentum: 0.9, time: 804____
# Accuracy score: 0.661 (0.109)
# ____features: 6, layers: 3, momentum: 0.0, time: 2780____
# Accuracy score: 0.707 (0.013)
# ____features: 6, layers: 3, momentum: 0.3, time: 1796____
# Accuracy score: 0.708 (0.010)
# ____features: 6, layers: 3, momentum: 0.1, time: 3004____
# Accuracy score: 0.707 (0.018)
# ____features: 6, layers: 3, momentum: 0.5, time: 2141____
# Accuracy score: 0.714 (0.004)
# ____features: 6, layers: 3, momentum: 0.9, time: 894____
# Accuracy score: 0.711 (0.007)
# ____features: 6, layers: 5, momentum: 0.0, time: 2287____
# Accuracy score: 0.708 (0.006)
# ____features: 6, layers: 5, momentum: 0.3, time: 2437____
# Accuracy score: 0.712 (0.006)
# ____features: 6, layers: 5, momentum: 0.1, time: 2026____
# Accuracy score: 0.709 (0.009)
# ____features: 6, layers: 5, momentum: 0.5, time: 1384____
# Accuracy score: 0.714 (0.004)
# ____features: 6, layers: 5, momentum: 0.9, time: 774____
# Accuracy score: 0.689 (0.036)
# ____features: 6, layers: 8, momentum: 0.0, time: 2381____
# Accuracy score: 0.713 (0.008)
# ____features: 6, layers: 8, momentum: 0.3, time: 1646____
# Accuracy score: 0.715 (0.002)
# ____features: 6, layers: 8, momentum: 0.1, time: 1847____
# Accuracy score: 0.707 (0.021)
# ____features: 6, layers: 8, momentum: 0.5, time: 1887____
# Accuracy score: 0.715 (0.001)
# ____features: 6, layers: 8, momentum: 0.9, time: 945____
# Accuracy score: 0.710 (0.007)
# ____features: 6, layers: 10, momentum: 0.0, time: 1788____
# Accuracy score: 0.711 (0.007)
# ____features: 6, layers: 10, momentum: 0.3, time: 2479____
# Accuracy score: 0.712 (0.005)
# ____features: 6, layers: 10, momentum: 0.1, time: 1652____
# Accuracy score: 0.711 (0.010)
# ____features: 6, layers: 10, momentum: 0.5, time: 1485____
# Accuracy score: 0.715 (0.001)
# ____features: 6, layers: 10, momentum: 0.9, time: 951____
#
# Accuracy score: 0.582 (0.175)
# ____features: 7, layers: 2, momentum: 0.0, time: 2975____
# Accuracy score: 0.712 (0.006)
# ____features: 7, layers: 2, momentum: 0.3, time: 3199____
# Accuracy score: 0.707 (0.015)
# ____features: 7, layers: 2, momentum: 0.1, time: 2002____
# Accuracy score: 0.709 (0.013)
# ____features: 7, layers: 2, momentum: 0.5, time: 2252____
# Accuracy score: 0.712 (0.005)
# ____features: 7, layers: 2, momentum: 0.9, time: 821____
# Accuracy score: 0.661 (0.127)
# ____features: 7, layers: 3, momentum: 0.0, time: 1246____
# Accuracy score: 0.712 (0.004)
# ____features: 7, layers: 3, momentum: 0.3, time: 2770____
# Accuracy score: 0.706 (0.012)
# ____features: 7, layers: 3, momentum: 0.1, time: 3540____
# Accuracy score: 0.711 (0.007)
# ____features: 7, layers: 3, momentum: 0.5, time: 2050____
# Accuracy score: 0.714 (0.003)
# ____features: 7, layers: 3, momentum: 0.9, time: 882____
# Accuracy score: 0.706 (0.018)
# ____features: 7, layers: 5, momentum: 0.0, time: 2706____
# Accuracy score: 0.701 (0.020)
# ____features: 7, layers: 5, momentum: 0.3, time: 2050____
# Accuracy score: 0.711 (0.006)
# ____features: 7, layers: 5, momentum: 0.1, time: 2404____
# Accuracy score: 0.715 (0.002)
# ____features: 7, layers: 5, momentum: 0.5, time: 989____
# Accuracy score: 0.713 (0.004)
# ____features: 7, layers: 5, momentum: 0.9, time: 1038____
# Accuracy score: 0.708 (0.017)
# ____features: 7, layers: 8, momentum: 0.0, time: 2379____
# Accuracy score: 0.712 (0.009)
# ____features: 7, layers: 8, momentum: 0.3, time: 2430____
# Accuracy score: 0.714 (0.003)
# ____features: 7, layers: 8, momentum: 0.1, time: 2076____
# Accuracy score: 0.715 (0.002)
# ____features: 7, layers: 8, momentum: 0.5, time: 1055____
# Accuracy score: 0.714 (0.002)
# ____features: 7, layers: 8, momentum: 0.9, time: 699____
# Accuracy score: 0.708 (0.013)
# ____features: 7, layers: 10, momentum: 0.0, time: 3237____
# Accuracy score: 0.712 (0.005)
# ____features: 7, layers: 10, momentum: 0.3, time: 2485____
# Accuracy score: 0.712 (0.005)
# ____features: 7, layers: 10, momentum: 0.1, time: 2322____
# Accuracy score: 0.713 (0.003)
# ____features: 7, layers: 10, momentum: 0.5, time: 1500____
# Accuracy score: 0.715 (0.002)
# ____features: 7, layers: 10, momentum: 0.9, time: 1113____
#
# Accuracy score: 0.711 (0.010)
# ____features: 8, layers: 2, momentum: 0.0, time: 1535____
# Accuracy score: 0.709 (0.016)
# ____features: 8, layers: 2, momentum: 0.3, time: 6801____
# Accuracy score: 0.707 (0.018)
# ____features: 8, layers: 2, momentum: 0.1, time: 2932____
# Accuracy score: 0.714 (0.002)
# ____features: 8, layers: 2, momentum: 0.5, time: 2809____
# Accuracy score: 0.714 (0.002)
# ____features: 8, layers: 2, momentum: 0.9, time: 1001____
# Accuracy score: 0.699 (0.025)
# ____features: 8, layers: 3, momentum: 0.0, time: 2725____
# Accuracy score: 0.703 (0.020)
# ____features: 8, layers: 3, momentum: 0.3, time: 1849____
# Accuracy score: 0.710 (0.012)
# ____features: 8, layers: 3, momentum: 0.1, time: 3909____
# Accuracy score: 0.705 (0.021)
# ____features: 8, layers: 3, momentum: 0.5, time: 2237____
# Accuracy score: 0.715 (0.001)
# ____features: 8, layers: 3, momentum: 0.9, time: 898____
# Accuracy score: 0.685 (0.034)
# ____features: 8, layers: 5, momentum: 0.0, time: 2370____
# Accuracy score: 0.710 (0.007)
# ____features: 8, layers: 5, momentum: 0.3, time: 2248____
# Accuracy score: 0.704 (0.021)
# ____features: 8, layers: 5, momentum: 0.1, time: 2364____
# Accuracy score: 0.711 (0.006)
# ____features: 8, layers: 5, momentum: 0.5, time: 2599____
# Accuracy score: 0.714 (0.005)
# ____features: 8, layers: 5, momentum: 0.9, time: 856____
# Accuracy score: 0.714 (0.002)
# ____features: 8, layers: 8, momentum: 0.0, time: 3325____
# Accuracy score: 0.712 (0.004)
# ____features: 8, layers: 8, momentum: 0.3, time: 2100____
# Accuracy score: 0.706 (0.013)
# ____features: 8, layers: 8, momentum: 0.1, time: 2587____
# Accuracy score: 0.713 (0.007)
# ____features: 8, layers: 8, momentum: 0.5, time: 1847____
# Accuracy score: 0.715 (0.001)
# ____features: 8, layers: 8, momentum: 0.9, time: 653____
# Accuracy score: 0.711 (0.008)
# ____features: 8, layers: 10, momentum: 0.0, time: 1966____
# Accuracy score: 0.712 (0.005)
# ____features: 8, layers: 10, momentum: 0.3, time: 2187____
# Accuracy score: 0.714 (0.001)
# ____features: 8, layers: 10, momentum: 0.1, time: 2298____
# Accuracy score: 0.714 (0.003)
# ____features: 8, layers: 10, momentum: 0.5, time: 1048____
# Accuracy score: 0.714 (0.003)
# ____features: 8, layers: 10, momentum: 0.9, time: 829____
#
# Accuracy score: 0.641 (0.129)
# ____features: 9, layers: 2, momentum: 0.0, time: 2888____
# Accuracy score: 0.701 (0.026)
# ____features: 9, layers: 2, momentum: 0.3, time: 3160____
# Accuracy score: 0.703 (0.019)
# ____features: 9, layers: 2, momentum: 0.1, time: 2558____
# Accuracy score: 0.708 (0.012)
# ____features: 9, layers: 2, momentum: 0.5, time: 1816____
# Accuracy score: 0.714 (0.002)
# ____features: 9, layers: 2, momentum: 0.9, time: 965____
# Accuracy score: 0.704 (0.020)
# ____features: 9, layers: 3, momentum: 0.0, time: 3225____
# Accuracy score: 0.707 (0.017)
# ____features: 9, layers: 3, momentum: 0.3, time: 1605____
# Accuracy score: 0.703 (0.026)
# ____features: 9, layers: 3, momentum: 0.1, time: 2729____
# Accuracy score: 0.711 (0.007)
# ____features: 9, layers: 3, momentum: 0.5, time: 919____
# Accuracy score: 0.711 (0.013)
# ____features: 9, layers: 3, momentum: 0.9, time: 876____
# Accuracy score: 0.710 (0.006)
# ____features: 9, layers: 5, momentum: 0.0, time: 1690____
# Accuracy score: 0.697 (0.028)
# ____features: 9, layers: 5, momentum: 0.3, time: 1831____
# Accuracy score: 0.705 (0.016)
# ____features: 9, layers: 5, momentum: 0.1, time: 3362____
# Accuracy score: 0.707 (0.021)
# ____features: 9, layers: 5, momentum: 0.5, time: 1447____
# Accuracy score: 0.715 (0.001)
# ____features: 9, layers: 5, momentum: 0.9, time: 809____
# Accuracy score: 0.710 (0.009)
# ____features: 9, layers: 8, momentum: 0.0, time: 2616____
# Accuracy score: 0.712 (0.010)
# ____features: 9, layers: 8, momentum: 0.3, time: 2023____
# Accuracy score: 0.711 (0.010)
# ____features: 9, layers: 8, momentum: 0.1, time: 1379____
# Accuracy score: 0.713 (0.003)
# ____features: 9, layers: 8, momentum: 0.5, time: 2258____
# Accuracy score: 0.712 (0.006)
# ____features: 9, layers: 8, momentum: 0.9, time: 631____
# Accuracy score: 0.711 (0.009)
# ____features: 9, layers: 10, momentum: 0.0, time: 1832____
# Accuracy score: 0.712 (0.006)
# ____features: 9, layers: 10, momentum: 0.3, time: 2118____
# Accuracy score: 0.704 (0.019)
# ____features: 9, layers: 10, momentum: 0.1, time: 2483____
# Accuracy score: 0.713 (0.004)
# ____features: 9, layers: 10, momentum: 0.5, time: 1779____
# Accuracy score: 0.715 (0.002)
# ____features: 9, layers: 10, momentum: 0.9, time: 951____
#
# Accuracy score: 0.612 (0.162)
# ____features: 10, layers: 2, momentum: 0.0, time: 4594____
# Accuracy score: 0.708 (0.013)
# ____features: 10, layers: 2, momentum: 0.3, time: 3787____
# Accuracy score: 0.689 (0.025)
# ____features: 10, layers: 2, momentum: 0.1, time: 2835____
# Accuracy score: 0.713 (0.004)
# ____features: 10, layers: 2, momentum: 0.5, time: 2663____
# Accuracy score: 0.710 (0.017)
# ____features: 10, layers: 2, momentum: 0.9, time: 665____
# Accuracy score: 0.704 (0.028)
# ____features: 10, layers: 3, momentum: 0.0, time: 2540____
# Accuracy score: 0.698 (0.021)
# ____features: 10, layers: 3, momentum: 0.3, time: 1535____
# Accuracy score: 0.701 (0.022)
# ____features: 10, layers: 3, momentum: 0.1, time: 2080____
# Accuracy score: 0.709 (0.009)
# ____features: 10, layers: 3, momentum: 0.5, time: 2362____
# Accuracy score: 0.715 (0.002)
# ____features: 10, layers: 3, momentum: 0.9, time: 2219____
# Accuracy score: 0.706 (0.012)
# ____features: 10, layers: 5, momentum: 0.0, time: 2383____
# Accuracy score: 0.703 (0.027)
# ____features: 10, layers: 5, momentum: 0.3, time: 2081____
# Accuracy score: 0.703 (0.017)
# ____features: 10, layers: 5, momentum: 0.1, time: 1599____
# Accuracy score: 0.713 (0.006)
# ____features: 10, layers: 5, momentum: 0.5, time: 1835____
# Accuracy score: 0.715 (0.002)
# ____features: 10, layers: 5, momentum: 0.9, time: 668____
# Accuracy score: 0.708 (0.018)
# ____features: 10, layers: 8, momentum: 0.0, time: 1662____
# Accuracy score: 0.710 (0.007)
# ____features: 10, layers: 8, momentum: 0.3, time: 1898____
# Accuracy score: 0.705 (0.011)
# ____features: 10, layers: 8, momentum: 0.1, time: 1361____
# Accuracy score: 0.706 (0.015)
# ____features: 10, layers: 8, momentum: 0.5, time: 1859____
# Accuracy score: 0.712 (0.007)
# ____features: 10, layers: 8, momentum: 0.9, time: 992____
# Accuracy score: 0.711 (0.007)
# ____features: 10, layers: 10, momentum: 0.0, time: 1933____
# Accuracy score: 0.711 (0.006)
# ____features: 10, layers: 10, momentum: 0.3, time: 2135____
# Accuracy score: 0.705 (0.015)
# ____features: 10, layers: 10, momentum: 0.1, time: 1038____
# Accuracy score: 0.715 (0.001)
# ____features: 10, layers: 10, momentum: 0.5, time: 1728____
# Accuracy score: 0.714 (0.002)
# ____features: 10, layers: 10, momentum: 0.9, time: 855____
