# %%
import pandas as pd
import numpy as np
import collections

from sklearn import preprocessing
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler, RobustScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_classif
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import RepeatedStratifiedKFold

import datetime


import seaborn as sns
import logging
import csv

from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# # About the data set

# %% [markdown]
# This data set contains 416 liver patient records and 167 non liver patient records.The data set was collected from north east of Andhra Pradesh, India. Selector is a class label used to divide into groups(liver patient or not). This data set contains 441 male patient records and 142 female patient records.
#
# Any patient whose age exceeded 89 is listed as being of age "90".
#
# ## Attributes
# 1. Age - Age of the patient
# 2. Gender - Gender of the patient
# 3. TB - Total Bilirubin
# 4. DB - Direct Bilirubin
# 5. Alkphos - Alkaline Phosphotase
# 6. Sgpt - Alamine Aminotransferase
# 7. Sgot - Aspartate Aminotransferase
# 8. TP - Total Protiens
# 9. ALB - Albumin
# 10. A/G Ratio - Albumin and Globulin Ratio
# 11. Selector field used to split the data into two sets (labeled by the experts)

# %% [markdown]
# # Read the data

# %%
# dataset location
dataset_location = "./dataset/ilpd_dataset.csv"

# column names
names = ['Age', 'Gender', 'TB', 'DB', 'ALKPHOS', 'SGPT', 'SGOT', 'TP', 'ALB', 'AG Ratio', 'selector']

# read dataset to pandas dataframe
df = pd.read_csv(dataset_location, names=names);

# %% [markdown]
# # Data analysis

# %%
# show first five cols of the dataset
print("Data shape: ", df.shape)
df.head()
# Out:
# Data shape:  (583, 11)
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio  selector
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3      0.90         1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2      0.74         1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3      0.89         1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4      1.00         1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4      0.40         1

# %%
# check for null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       583 non-null    int64
#  1   Gender    583 non-null    object
#  2   TB        583 non-null    float64
#  3   DB        583 non-null    float64
#  4   ALKPHOS   583 non-null    int64
#  5   SGPT      583 non-null    int64
#  6   SGOT      583 non-null    int64
#  7   TP        583 non-null    float64
#  8   ALB       583 non-null    float64
#  9   AG Ratio  579 non-null    float64
#  10  selector  583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %% [markdown]
# ## Histograms

# %%
df.hist(figsize=(14,11))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x106671e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a165b9bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a165faf50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1662ec10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1666ff90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a166a4c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a166e5490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1671ac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a16722810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a167641d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a167cd510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a16802d10>]],
#       dtype=object)

# %% [markdown]
# ## Compare number of samples

# %%
# show number of examples in each class
numb_of_classes = pd.value_counts(df['selector'], sort = True).sort_index()
numb_of_classes.plot(kind = 'bar')
plt.title("Number of examples for each class")
plt.xlabel("Selector")
plt.ylabel("Number of sample")
plt.savefig("./png_results/compare-numb-of-samples.png", dpi=300)

# %%
# show number of examples of each gender
numb_of_classes = pd.value_counts(df['Gender'], sort = True).sort_index()
numb_of_classes.plot(kind = 'bar')
plt.title("Number of examples for each gender")
plt.xlabel("Gender")
plt.ylabel("Number of samples")
plt.savefig("./png_results/compare-genders.png", dpi=300)

# %% [markdown]
# ## Compare mean features of each category

# %%
data1 = df[df['selector'] == 2] # no disease
data1 = data1[data1['Gender'] == 'Female']
data1 = data1.iloc[:,:-1]

data2 = df[df['selector'] == 1] # disease
data2 = data2[data2['Gender'] == 'Female']
data2 = data2.iloc[:,:-1]

fig = plt.figure(figsize=(10,15))

# people without disease
ax1 = fig.add_subplot(211)
ax1.grid()
ax1.set_title('Mean values of each feature (Females)',fontsize=13, weight='bold')
ax1.text(200,0.8,'liver patient',fontsize=20,horizontalalignment='center', color='orange', weight='bold')

plt.sca(ax1)

# people with disease
ax2 = fig.add_subplot(212,sharex=ax1)
ax2.grid()
ax2.set_title('Mean values of each feature (Female)',fontsize=13,weight='bold')
ax2.text(200,0.8,'non liver patient',fontsize=20,horizontalalignment='center',color='green',weight='bold')

plt.sca(ax2)

# show plots
sns.barplot(data=data1,ax=ax1,orient='horizontal', palette='bright')
sns.barplot(data=data2,ax=ax2,orient='horizontal', palette='bright')

fig.savefig("./png_results/patient-vs-nonpatient-features.png", dpi=300)

# %%
data1 = df[df['selector'] == 2] # no disease
data1 = data1[data1['Gender'] == 'Male']
data1 = data1.iloc[:,:-1]

data2 = df[df['selector'] == 1] # disease
data2 = data2[data2['Gender'] == 'Male']
data2 = data2.iloc[:,:-1]

fig = plt.figure(figsize=(10,15))

# people without disease
ax1 = fig.add_subplot(211)
ax1.grid()
ax1.set_title('Mean values of each feature (Males)',fontsize=13, weight='bold')
ax1.text(200,0.8,'liver patient',fontsize=20,horizontalalignment='center', color='orange', weight='bold')

plt.sca(ax1)

# people with disease
ax2 = fig.add_subplot(212,sharex=ax1)
ax2.grid()
ax2.set_title('Mean values of each feature (Males)',fontsize=13,weight='bold')
ax2.text(200,0.8,'non liver patient',fontsize=20,horizontalalignment='center',color='green',weight='bold')

plt.sca(ax2)

# show plots
sns.barplot(data=data1,ax=ax1,orient='horizontal', palette='bright')
sns.barplot(data=data2,ax=ax2,orient='horizontal', palette='bright')

# %% [markdown]
# As we can see above mean values of ALKPHOS, SGPT and SGOT tend to be much lower in liver patients than in non liver patients.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## change non-numerical values to integers

# %%
# transform Gender to numerical values
le = preprocessing.LabelEncoder()
le.fit(['Male','Female'])
df.loc[:,'Gender'] = le.transform(df['Gender'])

# %%
# transform selector from 1-2 to 0-1
df['selector'] = df['selector'].map({2:0, 1:1})

# display the result
df.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio  selector
# 0   65       0   0.7  0.1      187    16    18  6.8  3.3      0.90         1
# 1   62       1  10.9  5.5      699    64   100  7.5  3.2      0.74         1
# 2   62       1   7.3  4.1      490    60    68  7.0  3.3      0.89         1
# 3   58       1   1.0  0.4      182    14    20  6.8  3.4      1.00         1
# 4   72       1   3.9  2.0      195    27    59  7.3  2.4      0.40         1

# %% [markdown]
# ## remove empty values

# %%
# we can see that there are some null values in AG Ratio
df = df.dropna(how = 'any', axis = 0)

# check now
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 579 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       579 non-null    int64
#  1   Gender    579 non-null    int64
#  2   TB        579 non-null    float64
#  3   DB        579 non-null    float64
#  4   ALKPHOS   579 non-null    int64
#  5   SGPT      579 non-null    int64
#  6   SGOT      579 non-null    int64
#  7   TP        579 non-null    float64
#  8   ALB       579 non-null    float64
#  9   AG Ratio  579 non-null    float64
#  10  selector  579 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 54.3 KB

# %% [markdown]
# ## split data into features & classes

# %%
# split data into feture set X and labels y
y = df['selector']
X = df.drop('selector', axis=1)

# show first five cols of feature set
X.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio
# 0   65       0   0.7  0.1      187    16    18  6.8  3.3      0.90
# 1   62       1  10.9  5.5      699    64   100  7.5  3.2      0.74
# 2   62       1   7.3  4.1      490    60    68  7.0  3.3      0.89
# 3   58       1   1.0  0.4      182    14    20  6.8  3.4      1.00
# 4   72       1   3.9  2.0      195    27    59  7.3  2.4      0.40

# %% [markdown]
# ## feature selection

# %%
selected_X = SelectKBest(chi2, k=5).fit(X, y)
selected_X_df = pd.DataFrame({'Feature': list(X.columns),
                                    'Scores': selected_X.scores_})
selected_X_df.sort_values(by='Scores', ascending=False)
# Out:
#     Feature        Scores
# 6      SGOT  10138.860197
# 5      SGPT   6361.141943
# 4   ALKPHOS   3956.690967
# 2        TB    327.913058
# 3        DB    186.119776
# 0       Age     60.226677
# 8       ALB      2.966936
# 9  AG Ratio      1.658882
# 1    Gender      0.926483
# 7        TP      0.118535

# %% [markdown]
# ## display heatmap

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))
plt.title('Correlation of features')

# Draw the heatmap using seaborn
sns.heatmap(df.astype(float).corr(),linewidths=0.25,vmax=1.0, square=True, cmap="YlGnBu", linecolor='black',annot=True)

# %% [markdown]
# As we can see above:
# - DB & TB
# - SGOT & SGPT
# - ALB & TP
# - ALB & AG Ratio
#
# are highly correlated. Now we need to make a feature ranking to decide what features we want to use in classification.
#
# We can see that nothing correlates directly with selector - the highest correlation we can achieve with DB, but it's still only 0.25, but it's not a solid conclusion, because variables are biased (ex. most of people here are Males).

# %% [markdown]
# # Training & testing

# %%
def timestamp_ms():
    return int((datetime.datetime.utcnow() - datetime.datetime(1970, 1, 1)).total_seconds() * 1000)

# %%
def train_and_test(X, y, layer_size, solver, momentum=0.0):
    classifier = MLPClassifier(hidden_layer_sizes=(layer_size, ), solver=solver, momentum=momentum, max_iter=10000)
    cross_validator = RepeatedStratifiedKFold(n_splits=2, n_repeats=5, random_state=7890)
    scores = []

    for train_index, test_index in cross_validator.split(X, y):
        # create training & testing set
        X_train, X_test = X[train_index, : ], X[test_index, : ]
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
        # scale data
        scaler = MinMaxScaler()

        # fit to training data only & transform both
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)
        
        # fit & predict & calculate the score
        classifier.fit(X_train, y_train)
        predict = classifier.predict(X_test)
        acc_score = accuracy_score(y_test, predict)
        scores.append(acc_score)

    mean_score = np.mean(scores)
    std_score = np.std(scores)
    print("Accuracy score: %.3f (%.3f)" % (mean_score, std_score))
    return mean_score, std_score

# %%
min_features = 1
max_features = 11

layers = [2, 3, 5, 8, 10]
momentum_values = [0.0, 0.3, 0.1, 0.5, 0.9]

filename = 'results.csv'

with open(filename, 'w', newline='') as csvfile:
    fieldnames = ['features', 'layers', 'momentum', 'mean_score', 'std_score', 'time']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

    for k in range(min_features, max_features): 
        X_best = SelectKBest(chi2, k=k).fit_transform(X, y)

        for size in layers:
            for momentum in momentum_values:
                start = timestamp_ms()
                mean_score, std_score = train_and_test(X_best, y, size, 'sgd', momentum)
                stop = timestamp_ms()
                print("____features: {}, layers: {}, momentum: {}, time: {}____".format(k, size, momentum, stop-start))
                writer.writerow({'features': k, 'layers': size, 'momentum': momentum, 'mean_score': mean_score, 'std_score': std_score, 'time': stop-start})
        print("")
# Out:
# Accuracy score: 0.572 (0.140)
# ____features: 1, layers: 2, momentum: 0.0, time: 3667____
# Accuracy score: 0.700 (0.051)
# ____features: 1, layers: 2, momentum: 0.3, time: 1433____
# Accuracy score: 0.635 (0.115)
# ____features: 1, layers: 2, momentum: 0.1, time: 2929____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 2, momentum: 0.5, time: 1689____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 2, momentum: 0.9, time: 750____
# Accuracy score: 0.693 (0.030)
# ____features: 1, layers: 3, momentum: 0.0, time: 2848____
# Accuracy score: 0.713 (0.006)
# ____features: 1, layers: 3, momentum: 0.3, time: 2024____
# Accuracy score: 0.694 (0.034)
# ____features: 1, layers: 3, momentum: 0.1, time: 3161____
# Accuracy score: 0.715 (0.002)
# ____features: 1, layers: 3, momentum: 0.5, time: 1277____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 3, momentum: 0.9, time: 1702____
# Accuracy score: 0.696 (0.038)
# ____features: 1, layers: 5, momentum: 0.0, time: 1656____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 5, momentum: 0.3, time: 1551____
# Accuracy score: 0.706 (0.016)
# ____features: 1, layers: 5, momentum: 0.1, time: 2017____
# Accuracy score: 0.706 (0.018)
# ____features: 1, layers: 5, momentum: 0.5, time: 2369____
# Accuracy score: 0.716 (0.003)
# ____features: 1, layers: 5, momentum: 0.9, time: 1506____
# Accuracy score: 0.700 (0.030)
# ____features: 1, layers: 8, momentum: 0.0, time: 2048____
# Accuracy score: 0.711 (0.012)
# ____features: 1, layers: 8, momentum: 0.3, time: 1577____
# Accuracy score: 0.716 (0.002)
# ____features: 1, layers: 8, momentum: 0.1, time: 2026____
# Accuracy score: 0.713 (0.003)
# ____features: 1, layers: 8, momentum: 0.5, time: 1549____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 8, momentum: 0.9, time: 940____
# Accuracy score: 0.698 (0.037)
# ____features: 1, layers: 10, momentum: 0.0, time: 2144____
# Accuracy score: 0.703 (0.036)
# ____features: 1, layers: 10, momentum: 0.3, time: 3245____
# Accuracy score: 0.697 (0.031)
# ____features: 1, layers: 10, momentum: 0.1, time: 2599____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 10, momentum: 0.5, time: 1524____
# Accuracy score: 0.715 (0.001)
# ____features: 1, layers: 10, momentum: 0.9, time: 935____
#
# Accuracy score: 0.671 (0.065)
# ____features: 2, layers: 2, momentum: 0.0, time: 2793____
# Accuracy score: 0.693 (0.041)
# ____features: 2, layers: 2, momentum: 0.3, time: 2415____
# Accuracy score: 0.657 (0.069)
# ____features: 2, layers: 2, momentum: 0.1, time: 4382____
# Accuracy score: 0.696 (0.037)
# ____features: 2, layers: 2, momentum: 0.5, time: 1472____
# Accuracy score: 0.715 (0.001)
# ____features: 2, layers: 2, momentum: 0.9, time: 1305____
# Accuracy score: 0.640 (0.108)
# ____features: 2, layers: 3, momentum: 0.0, time: 2365____
# Accuracy score: 0.678 (0.055)
# ____features: 2, layers: 3, momentum: 0.3, time: 2137____
# Accuracy score: 0.674 (0.072)
# ____features: 2, layers: 3, momentum: 0.1, time: 1715____
# Accuracy score: 0.694 (0.043)
# ____features: 2, layers: 3, momentum: 0.5, time: 1787____
# Accuracy score: 0.714 (0.003)
# ____features: 2, layers: 3, momentum: 0.9, time: 1344____
# Accuracy score: 0.679 (0.051)
# ____features: 2, layers: 5, momentum: 0.0, time: 2672____
# Accuracy score: 0.684 (0.051)
# ____features: 2, layers: 5, momentum: 0.3, time: 1804____
# Accuracy score: 0.672 (0.041)
# ____features: 2, layers: 5, momentum: 0.1, time: 2243____
# Accuracy score: 0.698 (0.043)
# ____features: 2, layers: 5, momentum: 0.5, time: 1231____
# Accuracy score: 0.715 (0.005)
# ____features: 2, layers: 5, momentum: 0.9, time: 1075____
# Accuracy score: 0.710 (0.008)
# ____features: 2, layers: 8, momentum: 0.0, time: 1762____
# Accuracy score: 0.710 (0.014)
# ____features: 2, layers: 8, momentum: 0.3, time: 1407____
# Accuracy score: 0.697 (0.028)
# ____features: 2, layers: 8, momentum: 0.1, time: 3356____
# Accuracy score: 0.717 (0.010)
# ____features: 2, layers: 8, momentum: 0.5, time: 1573____
# Accuracy score: 0.715 (0.001)
# ____features: 2, layers: 8, momentum: 0.9, time: 746____
# Accuracy score: 0.703 (0.021)
# ____features: 2, layers: 10, momentum: 0.0, time: 1850____
# Accuracy score: 0.707 (0.017)
# ____features: 2, layers: 10, momentum: 0.3, time: 1817____
# Accuracy score: 0.650 (0.056)
# ____features: 2, layers: 10, momentum: 0.1, time: 3112____
# Accuracy score: 0.700 (0.021)
# ____features: 2, layers: 10, momentum: 0.5, time: 2304____
# Accuracy score: 0.715 (0.001)
# ____features: 2, layers: 10, momentum: 0.9, time: 1079____
#
# Accuracy score: 0.634 (0.072)
# ____features: 3, layers: 2, momentum: 0.0, time: 3687____
# Accuracy score: 0.714 (0.003)
# ____features: 3, layers: 2, momentum: 0.3, time: 1945____
# Accuracy score: 0.655 (0.089)
# ____features: 3, layers: 2, momentum: 0.1, time: 3656____
# Accuracy score: 0.685 (0.054)
# ____features: 3, layers: 2, momentum: 0.5, time: 1952____
# Accuracy score: 0.709 (0.011)
# ____features: 3, layers: 2, momentum: 0.9, time: 1156____
# Accuracy score: 0.651 (0.091)
# ____features: 3, layers: 3, momentum: 0.0, time: 2368____
# Accuracy score: 0.709 (0.016)
# ____features: 3, layers: 3, momentum: 0.3, time: 2553____
# Accuracy score: 0.709 (0.009)
# ____features: 3, layers: 3, momentum: 0.1, time: 1797____
# Accuracy score: 0.659 (0.060)
# ____features: 3, layers: 3, momentum: 0.5, time: 2673____
# Accuracy score: 0.714 (0.002)
# ____features: 3, layers: 3, momentum: 0.9, time: 1183____
# Accuracy score: 0.665 (0.081)
# ____features: 3, layers: 5, momentum: 0.0, time: 2581____
# Accuracy score: 0.681 (0.035)
# ____features: 3, layers: 5, momentum: 0.3, time: 2003____
# Accuracy score: 0.667 (0.041)
# ____features: 3, layers: 5, momentum: 0.1, time: 2382____
# Accuracy score: 0.700 (0.030)
# ____features: 3, layers: 5, momentum: 0.5, time: 1761____
# Accuracy score: 0.709 (0.012)
# ____features: 3, layers: 5, momentum: 0.9, time: 1263____
# Accuracy score: 0.667 (0.051)
# ____features: 3, layers: 8, momentum: 0.0, time: 1956____
# Accuracy score: 0.711 (0.022)
# ____features: 3, layers: 8, momentum: 0.3, time: 1964____
# Accuracy score: 0.683 (0.040)
# ____features: 3, layers: 8, momentum: 0.1, time: 1540____
# Accuracy score: 0.705 (0.021)
# ____features: 3, layers: 8, momentum: 0.5, time: 1694____
# Accuracy score: 0.715 (0.003)
# ____features: 3, layers: 8, momentum: 0.9, time: 853____
# Accuracy score: 0.710 (0.018)
# ____features: 3, layers: 10, momentum: 0.0, time: 1845____
# Accuracy score: 0.705 (0.015)
# ____features: 3, layers: 10, momentum: 0.3, time: 1817____
# Accuracy score: 0.691 (0.027)
# ____features: 3, layers: 10, momentum: 0.1, time: 2503____
# Accuracy score: 0.704 (0.023)
# ____features: 3, layers: 10, momentum: 0.5, time: 1492____
# Accuracy score: 0.710 (0.012)
# ____features: 3, layers: 10, momentum: 0.9, time: 964____
#
# Accuracy score: 0.679 (0.062)
# ____features: 4, layers: 2, momentum: 0.0, time: 2843____
# Accuracy score: 0.704 (0.023)
# ____features: 4, layers: 2, momentum: 0.3, time: 3365____
# Accuracy score: 0.628 (0.118)
# ____features: 4, layers: 2, momentum: 0.1, time: 3170____
# Accuracy score: 0.663 (0.085)
# ____features: 4, layers: 2, momentum: 0.5, time: 2442____
# Accuracy score: 0.707 (0.015)
# ____features: 4, layers: 2, momentum: 0.9, time: 1595____
# Accuracy score: 0.603 (0.097)
# ____features: 4, layers: 3, momentum: 0.0, time: 3345____
# Accuracy score: 0.689 (0.042)
# ____features: 4, layers: 3, momentum: 0.3, time: 2203____
# Accuracy score: 0.677 (0.045)
# ____features: 4, layers: 3, momentum: 0.1, time: 2805____
# Accuracy score: 0.701 (0.015)
# ____features: 4, layers: 3, momentum: 0.5, time: 3541____
# Accuracy score: 0.689 (0.048)
# ____features: 4, layers: 3, momentum: 0.9, time: 1732____
# Accuracy score: 0.694 (0.025)
# ____features: 4, layers: 5, momentum: 0.0, time: 2600____
# Accuracy score: 0.689 (0.037)
# ____features: 4, layers: 5, momentum: 0.3, time: 2868____
# Accuracy score: 0.672 (0.051)
# ____features: 4, layers: 5, momentum: 0.1, time: 2343____
# Accuracy score: 0.686 (0.038)
# ____features: 4, layers: 5, momentum: 0.5, time: 2271____
# Accuracy score: 0.716 (0.003)
# ____features: 4, layers: 5, momentum: 0.9, time: 1227____
# Accuracy score: 0.671 (0.034)
# ____features: 4, layers: 8, momentum: 0.0, time: 2146____
# Accuracy score: 0.699 (0.029)
# ____features: 4, layers: 8, momentum: 0.3, time: 2802____
# Accuracy score: 0.695 (0.036)
# ____features: 4, layers: 8, momentum: 0.1, time: 1981____
# Accuracy score: 0.703 (0.035)
# ____features: 4, layers: 8, momentum: 0.5, time: 2056____
# Accuracy score: 0.707 (0.013)
# ____features: 4, layers: 8, momentum: 0.9, time: 1000____
# Accuracy score: 0.680 (0.041)
# ____features: 4, layers: 10, momentum: 0.0, time: 2026____
# Accuracy score: 0.684 (0.049)
# ____features: 4, layers: 10, momentum: 0.3, time: 1990____
# Accuracy score: 0.707 (0.018)
# ____features: 4, layers: 10, momentum: 0.1, time: 1628____
# Accuracy score: 0.711 (0.015)
# ____features: 4, layers: 10, momentum: 0.5, time: 1543____
# Accuracy score: 0.709 (0.020)
# ____features: 4, layers: 10, momentum: 0.9, time: 1054____
#
# Accuracy score: 0.691 (0.029)
# ____features: 5, layers: 2, momentum: 0.0, time: 2036____
# Accuracy score: 0.648 (0.089)
# ____features: 5, layers: 2, momentum: 0.3, time: 2422____
# Accuracy score: 0.621 (0.096)
# ____features: 5, layers: 2, momentum: 0.1, time: 3860____
# Accuracy score: 0.643 (0.072)
# ____features: 5, layers: 2, momentum: 0.5, time: 2674____
# Accuracy score: 0.705 (0.022)
# ____features: 5, layers: 2, momentum: 0.9, time: 1757____
# Accuracy score: 0.647 (0.108)
# ____features: 5, layers: 3, momentum: 0.0, time: 2555____
# Accuracy score: 0.680 (0.052)
# ____features: 5, layers: 3, momentum: 0.3, time: 2339____
# Accuracy score: 0.677 (0.031)
# ____features: 5, layers: 3, momentum: 0.1, time: 2466____
# Accuracy score: 0.699 (0.021)
# ____features: 5, layers: 3, momentum: 0.5, time: 1956____
# Accuracy score: 0.698 (0.022)
# ____features: 5, layers: 3, momentum: 0.9, time: 1107____
# Accuracy score: 0.654 (0.046)
# ____features: 5, layers: 5, momentum: 0.0, time: 2609____
# Accuracy score: 0.693 (0.043)
# ____features: 5, layers: 5, momentum: 0.3, time: 1476____
# Accuracy score: 0.650 (0.053)
# ____features: 5, layers: 5, momentum: 0.1, time: 3459____
# Accuracy score: 0.681 (0.046)
# ____features: 5, layers: 5, momentum: 0.5, time: 1034____
# Accuracy score: 0.708 (0.017)
# ____features: 5, layers: 5, momentum: 0.9, time: 1310____
# Accuracy score: 0.697 (0.025)
# ____features: 5, layers: 8, momentum: 0.0, time: 1523____
# Accuracy score: 0.693 (0.020)
# ____features: 5, layers: 8, momentum: 0.3, time: 2237____
# Accuracy score: 0.677 (0.035)
# ____features: 5, layers: 8, momentum: 0.1, time: 2676____
# Accuracy score: 0.706 (0.024)
# ____features: 5, layers: 8, momentum: 0.5, time: 1719____
# Accuracy score: 0.707 (0.015)
# ____features: 5, layers: 8, momentum: 0.9, time: 1041____
# Accuracy score: 0.689 (0.030)
# ____features: 5, layers: 10, momentum: 0.0, time: 1948____
# Accuracy score: 0.699 (0.015)
# ____features: 5, layers: 10, momentum: 0.3, time: 1376____
# Accuracy score: 0.707 (0.011)
# ____features: 5, layers: 10, momentum: 0.1, time: 1485____
# Accuracy score: 0.704 (0.012)
# ____features: 5, layers: 10, momentum: 0.5, time: 1834____
# Accuracy score: 0.717 (0.005)
# ____features: 5, layers: 10, momentum: 0.9, time: 853____
#
# Accuracy score: 0.690 (0.048)
# ____features: 6, layers: 2, momentum: 0.0, time: 4430028____
# Accuracy score: 0.701 (0.029)
# ____features: 6, layers: 2, momentum: 0.3, time: 3369____
# Accuracy score: 0.699 (0.049)
# ____features: 6, layers: 2, momentum: 0.1, time: 4807____
# Accuracy score: 0.678 (0.070)
# ____features: 6, layers: 2, momentum: 0.5, time: 2886____
# Accuracy score: 0.699 (0.042)
# ____features: 6, layers: 2, momentum: 0.9, time: 1680____
# Accuracy score: 0.665 (0.038)
# ____features: 6, layers: 3, momentum: 0.0, time: 2547____
# Accuracy score: 0.706 (0.020)
# ____features: 6, layers: 3, momentum: 0.3, time: 2420____
# Accuracy score: 0.646 (0.053)
# ____features: 6, layers: 3, momentum: 0.1, time: 3934____
# Accuracy score: 0.696 (0.033)
# ____features: 6, layers: 3, momentum: 0.5, time: 2157____
# Accuracy score: 0.713 (0.007)
# ____features: 6, layers: 3, momentum: 0.9, time: 1807____
# Accuracy score: 0.690 (0.036)
# ____features: 6, layers: 5, momentum: 0.0, time: 3912____
# Accuracy score: 0.688 (0.040)
# ____features: 6, layers: 5, momentum: 0.3, time: 1979____
# Accuracy score: 0.675 (0.036)
# ____features: 6, layers: 5, momentum: 0.1, time: 2367____
# Accuracy score: 0.696 (0.035)
# ____features: 6, layers: 5, momentum: 0.5, time: 4026____
# Accuracy score: 0.708 (0.020)
# ____features: 6, layers: 5, momentum: 0.9, time: 1318____
# Accuracy score: 0.689 (0.037)
# ____features: 6, layers: 8, momentum: 0.0, time: 2750____
# Accuracy score: 0.687 (0.030)
# ____features: 6, layers: 8, momentum: 0.3, time: 1494____
# Accuracy score: 0.699 (0.034)
# ____features: 6, layers: 8, momentum: 0.1, time: 1806____
# Accuracy score: 0.704 (0.016)
# ____features: 6, layers: 8, momentum: 0.5, time: 2331____
# Accuracy score: 0.712 (0.005)
# ____features: 6, layers: 8, momentum: 0.9, time: 812____
# Accuracy score: 0.696 (0.030)
# ____features: 6, layers: 10, momentum: 0.0, time: 2276____
# Accuracy score: 0.692 (0.029)
# ____features: 6, layers: 10, momentum: 0.3, time: 2014____
# Accuracy score: 0.686 (0.036)
# ____features: 6, layers: 10, momentum: 0.1, time: 1813____
# Accuracy score: 0.701 (0.026)
# ____features: 6, layers: 10, momentum: 0.5, time: 2212____
# Accuracy score: 0.714 (0.004)
# ____features: 6, layers: 10, momentum: 0.9, time: 1017____
#
# Accuracy score: 0.561 (0.149)
# ____features: 7, layers: 2, momentum: 0.0, time: 5448____
# Accuracy score: 0.689 (0.043)
# ____features: 7, layers: 2, momentum: 0.3, time: 2890____
# Accuracy score: 0.681 (0.034)
# ____features: 7, layers: 2, momentum: 0.1, time: 2394____
# Accuracy score: 0.711 (0.009)
# ____features: 7, layers: 2, momentum: 0.5, time: 2463____
# Accuracy score: 0.708 (0.019)
# ____features: 7, layers: 2, momentum: 0.9, time: 1591____
# Accuracy score: 0.689 (0.032)
# ____features: 7, layers: 3, momentum: 0.0, time: 2141____
# Accuracy score: 0.694 (0.034)
# ____features: 7, layers: 3, momentum: 0.3, time: 1726____
# Accuracy score: 0.667 (0.042)
# ____features: 7, layers: 3, momentum: 0.1, time: 3840____
# Accuracy score: 0.670 (0.051)
# ____features: 7, layers: 3, momentum: 0.5, time: 1751____
# Accuracy score: 0.703 (0.018)
# ____features: 7, layers: 3, momentum: 0.9, time: 1430____
# Accuracy score: 0.686 (0.031)
# ____features: 7, layers: 5, momentum: 0.0, time: 2328____
# Accuracy score: 0.668 (0.057)
# ____features: 7, layers: 5, momentum: 0.3, time: 2626____
# Accuracy score: 0.680 (0.036)
# ____features: 7, layers: 5, momentum: 0.1, time: 2765____
# Accuracy score: 0.695 (0.029)
# ____features: 7, layers: 5, momentum: 0.5, time: 2349____
# Accuracy score: 0.696 (0.020)
# ____features: 7, layers: 5, momentum: 0.9, time: 1482____
# Accuracy score: 0.692 (0.034)
# ____features: 7, layers: 8, momentum: 0.0, time: 2008____
# Accuracy score: 0.664 (0.026)
# ____features: 7, layers: 8, momentum: 0.3, time: 2077____
# Accuracy score: 0.674 (0.041)
# ____features: 7, layers: 8, momentum: 0.1, time: 1690____
# Accuracy score: 0.689 (0.042)
# ____features: 7, layers: 8, momentum: 0.5, time: 2107____
# Accuracy score: 0.709 (0.013)
# ____features: 7, layers: 8, momentum: 0.9, time: 1319____
# Accuracy score: 0.665 (0.042)
# ____features: 7, layers: 10, momentum: 0.0, time: 2004____
# Accuracy score: 0.688 (0.029)
# ____features: 7, layers: 10, momentum: 0.3, time: 1937____
# Accuracy score: 0.691 (0.025)
# ____features: 7, layers: 10, momentum: 0.1, time: 1914____
# Accuracy score: 0.705 (0.029)
# ____features: 7, layers: 10, momentum: 0.5, time: 1655____
# Accuracy score: 0.711 (0.014)
# ____features: 7, layers: 10, momentum: 0.9, time: 1357____
#
# Accuracy score: 0.653 (0.090)
# ____features: 8, layers: 2, momentum: 0.0, time: 3530____
# Accuracy score: 0.697 (0.020)
# ____features: 8, layers: 2, momentum: 0.3, time: 2174____
# Accuracy score: 0.658 (0.063)
# ____features: 8, layers: 2, momentum: 0.1, time: 2973____
# Accuracy score: 0.682 (0.063)
# ____features: 8, layers: 2, momentum: 0.5, time: 2383____
# Accuracy score: 0.712 (0.009)
# ____features: 8, layers: 2, momentum: 0.9, time: 1553____
# Accuracy score: 0.683 (0.029)
# ____features: 8, layers: 3, momentum: 0.0, time: 2501____
# Accuracy score: 0.654 (0.074)
# ____features: 8, layers: 3, momentum: 0.3, time: 2590____
# Accuracy score: 0.628 (0.099)
# ____features: 8, layers: 3, momentum: 0.1, time: 2651____
# Accuracy score: 0.680 (0.044)
# ____features: 8, layers: 3, momentum: 0.5, time: 1936____
# Accuracy score: 0.709 (0.019)
# ____features: 8, layers: 3, momentum: 0.9, time: 1437____
# Accuracy score: 0.669 (0.035)
# ____features: 8, layers: 5, momentum: 0.0, time: 3680____
# Accuracy score: 0.696 (0.023)
# ____features: 8, layers: 5, momentum: 0.3, time: 2533____
# Accuracy score: 0.695 (0.023)
# ____features: 8, layers: 5, momentum: 0.1, time: 2718____
# Accuracy score: 0.682 (0.046)
# ____features: 8, layers: 5, momentum: 0.5, time: 2247____
# Accuracy score: 0.712 (0.013)
# ____features: 8, layers: 5, momentum: 0.9, time: 1698____
# Accuracy score: 0.675 (0.031)
# ____features: 8, layers: 8, momentum: 0.0, time: 2659____
# Accuracy score: 0.689 (0.049)
# ____features: 8, layers: 8, momentum: 0.3, time: 1820____
# Accuracy score: 0.684 (0.037)
# ____features: 8, layers: 8, momentum: 0.1, time: 2690____
# Accuracy score: 0.685 (0.033)
# ____features: 8, layers: 8, momentum: 0.5, time: 1776____
# Accuracy score: 0.707 (0.017)
# ____features: 8, layers: 8, momentum: 0.9, time: 1137____
# Accuracy score: 0.673 (0.049)
# ____features: 8, layers: 10, momentum: 0.0, time: 2301____
# Accuracy score: 0.684 (0.043)
# ____features: 8, layers: 10, momentum: 0.3, time: 2259____
# Accuracy score: 0.711 (0.015)
# ____features: 8, layers: 10, momentum: 0.1, time: 2087____
# Accuracy score: 0.699 (0.019)
# ____features: 8, layers: 10, momentum: 0.5, time: 1522____
# Accuracy score: 0.710 (0.014)
# ____features: 8, layers: 10, momentum: 0.9, time: 1232____
#
# Accuracy score: 0.683 (0.035)
# ____features: 9, layers: 2, momentum: 0.0, time: 4590____
# Accuracy score: 0.690 (0.030)
# ____features: 9, layers: 2, momentum: 0.3, time: 3045____
# Accuracy score: 0.661 (0.050)
# ____features: 9, layers: 2, momentum: 0.1, time: 2572____
# Accuracy score: 0.675 (0.051)
# ____features: 9, layers: 2, momentum: 0.5, time: 3100____
# Accuracy score: 0.704 (0.026)
# ____features: 9, layers: 2, momentum: 0.9, time: 1584____
# Accuracy score: 0.644 (0.065)
# ____features: 9, layers: 3, momentum: 0.0, time: 2572____
# Accuracy score: 0.701 (0.034)
# ____features: 9, layers: 3, momentum: 0.3, time: 2252____
# Accuracy score: 0.686 (0.037)
# ____features: 9, layers: 3, momentum: 0.1, time: 2862____
# Accuracy score: 0.689 (0.030)
# ____features: 9, layers: 3, momentum: 0.5, time: 1875____
# Accuracy score: 0.705 (0.019)
# ____features: 9, layers: 3, momentum: 0.9, time: 1612____
# Accuracy score: 0.652 (0.051)
# ____features: 9, layers: 5, momentum: 0.0, time: 2619____
# Accuracy score: 0.694 (0.014)
# ____features: 9, layers: 5, momentum: 0.3, time: 2111____
# Accuracy score: 0.691 (0.020)
# ____features: 9, layers: 5, momentum: 0.1, time: 2932____
# Accuracy score: 0.695 (0.025)
# ____features: 9, layers: 5, momentum: 0.5, time: 1552____
# Accuracy score: 0.713 (0.013)
# ____features: 9, layers: 5, momentum: 0.9, time: 1389____
# Accuracy score: 0.684 (0.030)
# ____features: 9, layers: 8, momentum: 0.0, time: 2184____
# Accuracy score: 0.699 (0.020)
# ____features: 9, layers: 8, momentum: 0.3, time: 1409____
# Accuracy score: 0.684 (0.017)
# ____features: 9, layers: 8, momentum: 0.1, time: 2451____
# Accuracy score: 0.699 (0.023)
# ____features: 9, layers: 8, momentum: 0.5, time: 1548____
# Accuracy score: 0.708 (0.017)
# ____features: 9, layers: 8, momentum: 0.9, time: 1223____
# Accuracy score: 0.685 (0.028)
# ____features: 9, layers: 10, momentum: 0.0, time: 2469____
# Accuracy score: 0.678 (0.029)
# ____features: 9, layers: 10, momentum: 0.3, time: 2146____
# Accuracy score: 0.681 (0.032)
# ____features: 9, layers: 10, momentum: 0.1, time: 2500____
# Accuracy score: 0.693 (0.025)
# ____features: 9, layers: 10, momentum: 0.5, time: 1749____
# Accuracy score: 0.709 (0.015)
# ____features: 9, layers: 10, momentum: 0.9, time: 1162____
#
# Accuracy score: 0.584 (0.142)
# ____features: 10, layers: 2, momentum: 0.0, time: 3776____
# Accuracy score: 0.674 (0.045)
# ____features: 10, layers: 2, momentum: 0.3, time: 2886____
# Accuracy score: 0.631 (0.117)
# ____features: 10, layers: 2, momentum: 0.1, time: 4115____
# Accuracy score: 0.670 (0.060)
# ____features: 10, layers: 2, momentum: 0.5, time: 2002____
# Accuracy score: 0.710 (0.012)
# ____features: 10, layers: 2, momentum: 0.9, time: 1378____
# Accuracy score: 0.667 (0.039)
# ____features: 10, layers: 3, momentum: 0.0, time: 2035____
# Accuracy score: 0.674 (0.046)
# ____features: 10, layers: 3, momentum: 0.3, time: 2350____
# Accuracy score: 0.687 (0.031)
# ____features: 10, layers: 3, momentum: 0.1, time: 2870____
# Accuracy score: 0.692 (0.031)
# ____features: 10, layers: 3, momentum: 0.5, time: 1416____
# Accuracy score: 0.712 (0.009)
# ____features: 10, layers: 3, momentum: 0.9, time: 1785____
# Accuracy score: 0.684 (0.027)
# ____features: 10, layers: 5, momentum: 0.0, time: 2475____
# Accuracy score: 0.703 (0.019)
# ____features: 10, layers: 5, momentum: 0.3, time: 2804____
# Accuracy score: 0.679 (0.038)
# ____features: 10, layers: 5, momentum: 0.1, time: 2751____
# Accuracy score: 0.683 (0.038)
# ____features: 10, layers: 5, momentum: 0.5, time: 2175____
# Accuracy score: 0.706 (0.018)
# ____features: 10, layers: 5, momentum: 0.9, time: 1820____
# Accuracy score: 0.669 (0.036)
# ____features: 10, layers: 8, momentum: 0.0, time: 2850____
# Accuracy score: 0.691 (0.021)
# ____features: 10, layers: 8, momentum: 0.3, time: 2165____
# Accuracy score: 0.676 (0.043)
# ____features: 10, layers: 8, momentum: 0.1, time: 1827____
# Accuracy score: 0.697 (0.026)
# ____features: 10, layers: 8, momentum: 0.5, time: 1802____
# Accuracy score: 0.702 (0.017)
# ____features: 10, layers: 8, momentum: 0.9, time: 1436____
# Accuracy score: 0.679 (0.038)
# ____features: 10, layers: 10, momentum: 0.0, time: 1720____
# Accuracy score: 0.693 (0.034)
# ____features: 10, layers: 10, momentum: 0.3, time: 2167____
# Accuracy score: 0.691 (0.029)
# ____features: 10, layers: 10, momentum: 0.1, time: 2636____
# Accuracy score: 0.682 (0.036)
# ____features: 10, layers: 10, momentum: 0.5, time: 1803____
# Accuracy score: 0.703 (0.018)
# ____features: 10, layers: 10, momentum: 0.9, time: 1108____
