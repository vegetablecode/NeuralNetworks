# %%
import pandas as pd
import numpy as np

from sklearn import preprocessing
from sklearn.utils import shuffle
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2, f_classif
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

import seaborn as sns

from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]

# %% [markdown]
# # Data Set information

# %% [markdown]
# This data set contains 416 liver patient records and 167 non liver patient records.The data set was collected from north east of Andhra Pradesh, India. Selector is a class label used to divide into groups(liver patient or not). This data set contains 441 male patient records and 142 female patient records.
#
# Any patient whose age exceeded 89 is listed as being of age "90".
#
# ## Attributes
# 1. Age - Age of the patient
# 2. Gender - Gender of the patient
# 3. TB - Total Bilirubin
# 4. DB - Direct Bilirubin
# 5. Alkphos - Alkaline Phosphotase
# 6. Sgpt - Alamine Aminotransferase
# 7. Sgot - Aspartate Aminotransferase
# 8. TP - Total Protiens
# 9. ALB - Albumin
# 10. A/G Ratio - Albumin and Globulin Ratio
# 11. Selector field used to split the data into two sets (labeled by the experts)

# %% [markdown]
# # Read the data

# %%
# dataset location
dataset_location = "./dataset/ilpd_dataset.csv"

# column names
names = ['Age', 'Gender', 'TB', 'DB', 'ALKPHOS', 'SGPT', 'SGOT', 'TP', 'ALB', 'AG Ratio', 'selector']

# read dataset to pandas dataframe
df = pd.read_csv(dataset_location, names=names);

# show first five cols of the dataset
print("Data shape: ", df.shape)
df.head()
# Out:
# Data shape:  (583, 11)
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio  selector
# 0   65  Female   0.7  0.1      187    16    18  6.8  3.3      0.90         1
# 1   62    Male  10.9  5.5      699    64   100  7.5  3.2      0.74         1
# 2   62    Male   7.3  4.1      490    60    68  7.0  3.3      0.89         1
# 3   58    Male   1.0  0.4      182    14    20  6.8  3.4      1.00         1
# 4   72    Male   3.9  2.0      195    27    59  7.3  2.4      0.40         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       583 non-null    int64
#  1   Gender    583 non-null    object
#  2   TB        583 non-null    float64
#  3   DB        583 non-null    float64
#  4   ALKPHOS   583 non-null    int64
#  5   SGPT      583 non-null    int64
#  6   SGOT      583 non-null    int64
#  7   TP        583 non-null    float64
#  8   ALB       583 non-null    float64
#  9   AG Ratio  579 non-null    float64
#  10  selector  583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
df.describe()
# Out:
#               Age          TB          DB      ALKPHOS         SGPT  \
# count  583.000000  583.000000  583.000000   583.000000   583.000000
# mean    44.746141    3.298799    1.486106   290.576329    80.713551
# std     16.189833    6.209522    2.808498   242.937989   182.620356
# min      4.000000    0.400000    0.100000    63.000000    10.000000
# 25%     33.000000    0.800000    0.200000   175.500000    23.000000
# 50%     45.000000    1.000000    0.300000   208.000000    35.000000
# 75%     58.000000    2.600000    1.300000   298.000000    60.500000
# max     90.000000   75.000000   19.700000  2110.000000  2000.000000
#
#               SGOT          TP         ALB    AG Ratio    selector
# count   583.000000  583.000000  583.000000  579.000000  583.000000
# mean    109.910806    6.483190    3.141852    0.947064    1.286449
# std     288.918529    1.085451    0.795519    0.319592    0.452490
# min      10.000000    2.700000    0.900000    0.300000    1.000000
# 25%      25.000000    5.800000    2.600000    0.700000    1.000000
# 50%      42.000000    6.600000    3.100000    0.930000    1.000000
# 75%      87.000000    7.200000    3.800000    1.100000    2.000000
# max    4929.000000    9.600000    5.500000    2.800000    2.000000

# %%
df.hist(figsize=(14,11))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a15dc33d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a17f00b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a17f42e50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a17f78ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a17fb7e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a17fedb10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1802cf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18062b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1806c690>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a180ad050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a18115ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1814ab90>]],
#       dtype=object)

# %%
numb_of_classes = pd.value_counts(df['selector'], sort = True).sort_index()
numb_of_classes.plot(kind = 'bar')
plt.title("ILPD Histogram")
plt.xlabel("Dataset")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## change non-numerical values to integers

# %%
# transform Gender to numerical values
le = preprocessing.LabelEncoder()
le.fit(['Male','Female'])
df.loc[:,'Gender'] = le.transform(df['Gender'])

# %%
# transform selector from 1-2 to 0-1
df['selector'] = df['selector'].map({2:0, 1:1})

df.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio  selector
# 0   65       0   0.7  0.1      187    16    18  6.8  3.3      0.90         1
# 1   62       1  10.9  5.5      699    64   100  7.5  3.2      0.74         1
# 2   62       1   7.3  4.1      490    60    68  7.0  3.3      0.89         1
# 3   58       1   1.0  0.4      182    14    20  6.8  3.4      1.00         1
# 4   72       1   3.9  2.0      195    27    59  7.3  2.4      0.40         1

# %% [markdown]
# ## remove empty values

# %%
# we can see that there are some null values in AG Ratio
df = df.dropna(how = 'any', axis = 0)

# check now
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 579 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       579 non-null    int64
#  1   Gender    579 non-null    int64
#  2   TB        579 non-null    float64
#  3   DB        579 non-null    float64
#  4   ALKPHOS   579 non-null    int64
#  5   SGPT      579 non-null    int64
#  6   SGOT      579 non-null    int64
#  7   TP        579 non-null    float64
#  8   ALB       579 non-null    float64
#  9   AG Ratio  579 non-null    float64
#  10  selector  579 non-null    int64
# dtypes: float64(5), int64(6)
# memory usage: 54.3 KB

# %%
df.head()
# Out:
#    Age  Gender    TB   DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio  selector
# 0   65       0   0.7  0.1      187    16    18  6.8  3.3      0.90         1
# 1   62       1  10.9  5.5      699    64   100  7.5  3.2      0.74         1
# 2   62       1   7.3  4.1      490    60    68  7.0  3.3      0.89         1
# 3   58       1   1.0  0.4      182    14    20  6.8  3.4      1.00         1
# 4   72       1   3.9  2.0      195    27    59  7.3  2.4      0.40         1

# %%
df.describe()
# Out:
#               Age      Gender          TB          DB      ALKPHOS  \
# count  579.000000  579.000000  579.000000  579.000000   579.000000
# mean    44.782383    0.758204    3.315371    1.494128   291.366149
# std     16.221786    0.428542    6.227716    2.816499   243.561863
# min      4.000000    0.000000    0.400000    0.100000    63.000000
# 25%     33.000000    1.000000    0.800000    0.200000   175.500000
# 50%     45.000000    1.000000    1.000000    0.300000   208.000000
# 75%     58.000000    1.000000    2.600000    1.300000   298.000000
# max     90.000000    1.000000   75.000000   19.700000  2110.000000
#
#               SGPT         SGOT          TP         ALB    AG Ratio  \
# count   579.000000   579.000000  579.000000  579.000000  579.000000
# mean     81.126079   110.414508    6.481693    3.138515    0.947064
# std     183.182845   289.850034    1.084641    0.794435    0.319592
# min      10.000000    10.000000    2.700000    0.900000    0.300000
# 25%      23.000000    25.000000    5.800000    2.600000    0.700000
# 50%      35.000000    42.000000    6.600000    3.100000    0.930000
# 75%      61.000000    87.000000    7.200000    3.800000    1.100000
# max    2000.000000  4929.000000    9.600000    5.500000    2.800000
#
#          selector
# count  579.000000
# mean     0.715026
# std      0.451792
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# ## split data into training & testing set

# %%
# shuffle data
df = shuffle(df)

# split data into feture set X and labels y
y = df['selector']
X = df.drop('selector', axis=1)

# show first five cols of feature set
X.head()
# Out:
#      Age  Gender    TB    DB  ALKPHOS  SGPT  SGOT   TP  ALB  AG Ratio
# 423   53       1   1.6   0.9      178    44    59  6.5  3.9       1.5
# 348   70       1   1.3   0.4      358    19    14  6.1  2.8       0.8
# 142   30       1   1.6   0.4      332    84   139  5.6  2.7       0.9
# 311   54       0  23.2  12.6      574    43    47  7.2  3.5       0.9
# 439   42       0   0.8   0.2      168    25    18  6.2  3.1       1.0

# %%
# show unique labels
y.unique()
# Out:
# array([0, 1])

# %%
# set number of test samples
test_size = 0.2
X_train_raw, X_test_raw, y_train, y_test = train_test_split(X, y, test_size=test_size)

# %%
print("Number of test samples (X): ", X_test_raw.shape[0])
print("Number of test samples (y): ", y_test.shape[0])

print("Number of train samples (X): ", X_train_raw.shape[0])
print("Number of train samples (y): ", y_train.shape[0])
# Out:
# Number of test samples (X):  116
# Number of test samples (y):  116
# Number of train samples (X):  463
# Number of train samples (y):  463

# %% [markdown]
# ## feature scaling

# %%
scaler = MinMaxScaler()

X_train_before = X_train_raw.copy(deep=True)

# transform training and testing data
X_train = scaler.fit_transform(X_train_raw)
X_test = scaler.transform(X_test_raw)

# %%
# show train set
X_train = pd.DataFrame(X_train, columns=X_train_before.columns)
X_train.head()
# Out:
#         Age  Gender        TB        DB   ALKPHOS      SGPT      SGOT  \
# 0  0.406977     1.0  0.083110  0.159341  0.082924  0.090452  0.320163
# 1  0.430233     1.0  0.030831  0.065934  0.282051  0.066332  0.019755
# 2  0.604651     1.0  0.009383  0.021978  0.063830  0.010050  0.010899
# 3  0.651163     1.0  0.037534  0.093407  0.374795  0.034673  0.045981
# 4  0.034884     1.0  0.001340  0.000000  0.157665  0.009045  0.013965
#
#          TP       ALB  AG Ratio
# 0  0.176471  0.173913     0.160
# 1  0.764706  0.673913     0.280
# 2  0.602941  0.630435     0.360
# 3  0.735294  0.500000     0.156
# 4  0.750000  0.717391     0.320

# %%
# show test set
X_test = pd.DataFrame(X_test, columns=X_train_before.columns)
X_test.head()
# Out:
#         Age  Gender        TB        DB   ALKPHOS      SGPT      SGOT  \
# 0  0.755814     1.0  0.006702  0.005495  0.082924  0.011055  0.004768
# 1  0.313953     0.0  0.005362  0.005495  0.082924  0.002513  0.003747
# 2  0.255814     0.0  0.004021  0.005495  0.044190  0.013065  0.007834
# 3  0.348837     1.0  0.044236  0.109890  0.232951  0.052764  0.027589
# 4  0.651163     1.0  0.071046  0.148352  0.082379  0.202010  0.286104
#
#          TP       ALB  AG Ratio
# 0  0.602941  0.456522     0.160
# 1  0.705882  0.673913     0.320
# 2  0.794118  0.739130     0.320
# 3  0.544118  0.413043     0.160
# 4  0.661765  0.500000     0.192

# %%
# show difference
labels = X_train_before.columns
fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(10, 10))
bw_value = 1.5

ax1.set_title('Before Scaling')
sns.kdeplot(X_train_before['Age'], ax=ax1, bw=bw_value)
sns.kdeplot(X_train_before['TB'], ax=ax1, bw=bw_value)
sns.kdeplot(X_train_before['DB'], ax=ax1, bw=bw_value)
sns.kdeplot(X_train_before['ALKPHOS'], ax=ax1, bw=bw_value)
sns.kdeplot(X_train_before['SGPT'], ax=ax1, bw=bw_value)
sns.kdeplot(X_train_before['SGOT'], ax=ax1, bw=bw_value)
sns.kdeplot(X_train_before['TP'], ax=ax1, bw=bw_value)
sns.kdeplot(X_train_before['ALB'], ax=ax1, bw=bw_value)
sns.kdeplot(X_train_before['AG Ratio'], ax=ax1, bw=bw_value)
sns.kdeplot(X_train_before['Gender'], ax=ax1, bw=bw_value)

ax2.set_title('After Standard Scaler')
sns.kdeplot(X_train['TB'], ax=ax2, bw=bw_value)
sns.kdeplot(X_train['DB'], ax=ax2, bw=bw_value)
sns.kdeplot(X_train['ALKPHOS'], ax=ax2, bw=bw_value)
sns.kdeplot(X_train['SGPT'], ax=ax2, bw=bw_value)
sns.kdeplot(X_train['SGOT'], ax=ax2, bw=bw_value)
sns.kdeplot(X_train['TP'], ax=ax2, bw=bw_value)
sns.kdeplot(X_train['ALB'], ax=ax2, bw=bw_value)
sns.kdeplot(X_train['AG Ratio'], ax=ax2, bw=bw_value)
sns.kdeplot(X_train['Gender'], ax=ax2, bw=bw_value)

plt.show()

# %% [markdown]
# # Feature selection

# %% [markdown]
# ## check correlations between the features heatmap

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))
plt.title('Pearson Correlation of liver disease Features')

# Draw the heatmap using seaborn
sns.heatmap(df.astype(float).corr(),linewidths=0.25,vmax=1.0, square=True, cmap="YlGnBu", linecolor='black',annot=True)

# %% [markdown]
# As we can see above:
# - DB & TB
# - SGOT & SGPT
# - ALB & TP
# - ALB & AG Ratio
#
# are highly correlated. Now we need to make a feature ranking to decide what features we want to use in classification.

# %% [markdown]
# # RAW TEST

# %%
#using scaled data MLP
mlp = MLPClassifier(hidden_layer_sizes=(30), max_iter=2000, alpha=1e-4,
                  solver='adam', verbose=10, tol=1e-4, random_state=1,
                  learning_rate_init=0.01)
mlp.fit(X_train, y_train)

print("MLP on scaled test data:")
print("Accuracy:", mlp.score(X_test, y_test))
print("Precision:", precision_score(y_test, mlp.predict(X_test)))
print("Recall:", recall_score(y_test, mlp.predict(X_test)))
print("F-1 score:", f1_score(y_test, mlp.predict(X_test)))
# Out:
# Iteration 1, loss = 0.62158948
# Iteration 2, loss = 0.60797411
# Iteration 3, loss = 0.60341326
# Iteration 4, loss = 0.59668042
# Iteration 5, loss = 0.58703783
# Iteration 6, loss = 0.57932724
# Iteration 7, loss = 0.57198775
# Iteration 8, loss = 0.56484933
# Iteration 9, loss = 0.55940999
# Iteration 10, loss = 0.55268569
# Iteration 11, loss = 0.54606964
# Iteration 12, loss = 0.53976167
# Iteration 13, loss = 0.53331760
# Iteration 14, loss = 0.53187558
# Iteration 15, loss = 0.52897717
# Iteration 16, loss = 0.52228883
# Iteration 17, loss = 0.52506180
# Iteration 18, loss = 0.51825597
# Iteration 19, loss = 0.52265316
# Iteration 20, loss = 0.52396762
# Iteration 21, loss = 0.51561272
# Iteration 22, loss = 0.52137473
# Iteration 23, loss = 0.51621801
# Iteration 24, loss = 0.51425889
# Iteration 25, loss = 0.51151937
# Iteration 26, loss = 0.51449494
# Iteration 27, loss = 0.51393420
# Iteration 28, loss = 0.51025425
# Iteration 29, loss = 0.51184370
# Iteration 30, loss = 0.51061914
# Iteration 31, loss = 0.51150446
# Iteration 32, loss = 0.50969502
# Iteration 33, loss = 0.50855043
# Iteration 34, loss = 0.50869464
# Iteration 35, loss = 0.50983614
# Iteration 36, loss = 0.50803651
# Iteration 37, loss = 0.50714334
# Iteration 38, loss = 0.50729687
# Iteration 39, loss = 0.50600741
# Iteration 40, loss = 0.50445839
# Iteration 41, loss = 0.50629743
# Iteration 42, loss = 0.50366893
# Iteration 43, loss = 0.50639766
# Iteration 44, loss = 0.50736972
# Iteration 45, loss = 0.50702045
# Iteration 46, loss = 0.50782244
# Iteration 47, loss = 0.50586367
# Iteration 48, loss = 0.50824882
# Iteration 49, loss = 0.50294700
# Iteration 50, loss = 0.50493109
# Iteration 51, loss = 0.50635639
# Iteration 52, loss = 0.50250710
# Iteration 53, loss = 0.50409705
# Iteration 54, loss = 0.50346383
# Iteration 55, loss = 0.50381797
# Iteration 56, loss = 0.50199949
# Iteration 57, loss = 0.50099809
# Iteration 58, loss = 0.50049451
# Iteration 59, loss = 0.50070670
# Iteration 60, loss = 0.50042269
# Iteration 61, loss = 0.49981456
# Iteration 62, loss = 0.50161996
# Iteration 63, loss = 0.50029160
# Iteration 64, loss = 0.49898145
# Iteration 65, loss = 0.50257131
# Iteration 66, loss = 0.50092128
# Iteration 67, loss = 0.50079858
# Iteration 68, loss = 0.49970421
# Iteration 69, loss = 0.49971490
# Iteration 70, loss = 0.49984646
# Iteration 71, loss = 0.49862586
# Iteration 72, loss = 0.49861364
# Iteration 73, loss = 0.49756015
# Iteration 74, loss = 0.49943308
# Iteration 75, loss = 0.49950084
# Iteration 76, loss = 0.49796244
# Iteration 77, loss = 0.49972416
# Iteration 78, loss = 0.49745284
# Iteration 79, loss = 0.49851076
# Iteration 80, loss = 0.49717766
# Iteration 81, loss = 0.49838247
# Iteration 82, loss = 0.49832991
# Iteration 83, loss = 0.49670980
# Iteration 84, loss = 0.49816323
# Iteration 85, loss = 0.49593059
# Iteration 86, loss = 0.49578044
# Iteration 87, loss = 0.49631624
# Iteration 88, loss = 0.49547913
# Iteration 89, loss = 0.49510966
# Iteration 90, loss = 0.49608408
# Iteration 91, loss = 0.49693212
# Iteration 92, loss = 0.49633559
# Iteration 93, loss = 0.49586747
# Iteration 94, loss = 0.49478653
# Iteration 95, loss = 0.49502605
# Iteration 96, loss = 0.49573768
# Iteration 97, loss = 0.49612660
# Iteration 98, loss = 0.49819844
# Iteration 99, loss = 0.49717085
# Iteration 100, loss = 0.49744986
# Iteration 101, loss = 0.49416810
# Iteration 102, loss = 0.49442915
# Iteration 103, loss = 0.49477777
# Iteration 104, loss = 0.49297446
# Iteration 105, loss = 0.49236931
# Iteration 106, loss = 0.49368031
# Iteration 107, loss = 0.49264853
# Iteration 108, loss = 0.49299983
# Iteration 109, loss = 0.49269152
# Iteration 110, loss = 0.49196828
# Iteration 111, loss = 0.49263429
# Iteration 112, loss = 0.49271651
# Iteration 113, loss = 0.49514712
# Iteration 114, loss = 0.49281328
# Iteration 115, loss = 0.49413077
# Iteration 116, loss = 0.49065476
# Iteration 117, loss = 0.49272468
# Iteration 118, loss = 0.49386650
# Iteration 119, loss = 0.49062679
# Iteration 120, loss = 0.49104135
# Iteration 121, loss = 0.49124879
# Iteration 122, loss = 0.49109441
# Iteration 123, loss = 0.49311876
# Iteration 124, loss = 0.49253770
# Iteration 125, loss = 0.49200478
# Iteration 126, loss = 0.49060139
# Iteration 127, loss = 0.49128689
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLP on scaled test data:
# Accuracy: 0.7327586206896551
# Precision: 0.7714285714285715
# Recall: 0.9204545454545454
# F-1 score: 0.839378238341969

# %% [markdown]
# # Training and predictions (no feature selection)

# %%
df.shape
# Out:
# (579, 11)

# %%
# create 2 layers of 20 nodes each + 2000 iterations
mlp = MLPClassifier(solver='adam', hidden_layer_sizes=(20), max_iter=2000, activation='tanh', learning_rate_init=0.02)

# train algorithm on training data
mlp.fit(X_train, y_train.values.ravel())

# make predictions
predictions = mlp.predict(X_test)

# accuracy score
acc = accuracy_score(y_test, predictions)

# %% [markdown]
# # Check the results

# %%
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test, predictions))
print("Accuracy Using MLP: " + str(acc)+'\n')
# Out:
# [[ 3 25]
#  [10 78]]
#               precision    recall  f1-score   support
#
#            0       0.23      0.11      0.15        28
#            1       0.76      0.89      0.82        88
#
#     accuracy                           0.70       116
#    macro avg       0.49      0.50      0.48       116
# weighted avg       0.63      0.70      0.65       116
#
# Accuracy Using MLP: 0.6982758620689655

# %% [markdown]
# # Training and predictions (feature selection)

# %% [markdown]
# ## select features

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

new_X_train = X_train.filter(['DB', 'TB', 'SGOT', 'SGPT', 'ALB', 'TP', 'AG Ratio'], axis=1)
new_X_test = X_test.filter(['DB', 'TB', 'SGOT', 'SGPT', 'ALB', 'TP', 'AG Ratio'], axis=1)


new_X_train.head()
# Out:
#          DB        TB      SGOT      SGPT       ALB        TP  AG Ratio
# 0  0.159341  0.083110  0.320163  0.090452  0.173913  0.176471     0.160
# 1  0.065934  0.030831  0.019755  0.066332  0.673913  0.764706     0.280
# 2  0.021978  0.009383  0.010899  0.010050  0.630435  0.602941     0.360
# 3  0.093407  0.037534  0.045981  0.034673  0.500000  0.735294     0.156
# 4  0.000000  0.001340  0.013965  0.009045  0.717391  0.750000     0.320

# %%
new_X_test.head()
# Out:
#          DB        TB      SGOT      SGPT       ALB        TP  AG Ratio
# 0  0.005495  0.006702  0.004768  0.011055  0.456522  0.602941     0.160
# 1  0.005495  0.005362  0.003747  0.002513  0.673913  0.705882     0.320
# 2  0.005495  0.004021  0.007834  0.013065  0.739130  0.794118     0.320
# 3  0.109890  0.044236  0.027589  0.052764  0.413043  0.544118     0.160
# 4  0.148352  0.071046  0.286104  0.202010  0.500000  0.661765     0.192

# %% [markdown]
# ## train & test

# %%
# create 2 layers of 20 nodes each + 2000 iterations
#mlp = MLPClassifier(solver='adam', hidden_layer_sizes=(30), max_iter=4000, activation='tanh', learning_rate_init=0.02)
mlp = MLPClassifier(hidden_layer_sizes=(30), max_iter=2000, alpha=1e-4,
                  solver='adam', verbose=10, tol=1e-4, random_state=1,
                  learning_rate_init=0.01)

# train algorithm on training data
mlp.fit(new_X_train, y_train.values.ravel())

# make predictions
predictions = mlp.predict(new_X_test)

# accuracy score
acc = accuracy_score(y_test, predictions)

print(confusion_matrix(y_test,predictions))
print(classification_report(y_test, predictions))
print("Accuracy Using MLP: " + str(acc)+'\n')
# Out:
# Iteration 1, loss = 0.62711890
# Iteration 2, loss = 0.59756098
# Iteration 3, loss = 0.59475089
# Iteration 4, loss = 0.59567266
# Iteration 5, loss = 0.58878407
# Iteration 6, loss = 0.57955709
# Iteration 7, loss = 0.57412126
# Iteration 8, loss = 0.57062087
# Iteration 9, loss = 0.56625589
# Iteration 10, loss = 0.56301025
# Iteration 11, loss = 0.55828116
# Iteration 12, loss = 0.55428182
# Iteration 13, loss = 0.55107698
# Iteration 14, loss = 0.54764720
# Iteration 15, loss = 0.54484758
# Iteration 16, loss = 0.54232260
# Iteration 17, loss = 0.53959430
# Iteration 18, loss = 0.53819452
# Iteration 19, loss = 0.53557699
# Iteration 20, loss = 0.53408975
# Iteration 21, loss = 0.53272042
# Iteration 22, loss = 0.53124298
# Iteration 23, loss = 0.52942567
# Iteration 24, loss = 0.52808797
# Iteration 25, loss = 0.52822252
# Iteration 26, loss = 0.52657658
# Iteration 27, loss = 0.52531564
# Iteration 28, loss = 0.52630752
# Iteration 29, loss = 0.52409889
# Iteration 30, loss = 0.52349852
# Iteration 31, loss = 0.52411707
# Iteration 32, loss = 0.52318964
# Iteration 33, loss = 0.52310382
# Iteration 34, loss = 0.52206370
# Iteration 35, loss = 0.52138198
# Iteration 36, loss = 0.52192664
# Iteration 37, loss = 0.52293893
# Iteration 38, loss = 0.52125591
# Iteration 39, loss = 0.52054235
# Iteration 40, loss = 0.52038405
# Iteration 41, loss = 0.52089429
# Iteration 42, loss = 0.52037392
# Iteration 43, loss = 0.52123581
# Iteration 44, loss = 0.52219343
# Iteration 45, loss = 0.51841023
# Iteration 46, loss = 0.52284178
# Iteration 47, loss = 0.52203304
# Iteration 48, loss = 0.51860778
# Iteration 49, loss = 0.52221610
# Iteration 50, loss = 0.52055868
# Iteration 51, loss = 0.51870620
# Iteration 52, loss = 0.51878103
# Iteration 53, loss = 0.51929789
# Iteration 54, loss = 0.51848692
# Iteration 55, loss = 0.52183003
# Iteration 56, loss = 0.51829159
# Iteration 57, loss = 0.51814209
# Iteration 58, loss = 0.51989527
# Iteration 59, loss = 0.51868316
# Iteration 60, loss = 0.51771582
# Iteration 61, loss = 0.52074632
# Iteration 62, loss = 0.51981296
# Iteration 63, loss = 0.51707517
# Iteration 64, loss = 0.51800417
# Iteration 65, loss = 0.51763871
# Iteration 66, loss = 0.51790710
# Iteration 67, loss = 0.51752168
# Iteration 68, loss = 0.51782635
# Iteration 69, loss = 0.51711669
# Iteration 70, loss = 0.51818325
# Iteration 71, loss = 0.51851319
# Iteration 72, loss = 0.51623450
# Iteration 73, loss = 0.51735340
# Iteration 74, loss = 0.51953395
# Iteration 75, loss = 0.51658459
# Iteration 76, loss = 0.51650124
# Iteration 77, loss = 0.51667402
# Iteration 78, loss = 0.51583893
# Iteration 79, loss = 0.51745256
# Iteration 80, loss = 0.51806505
# Iteration 81, loss = 0.51919553
# Iteration 82, loss = 0.51742441
# Iteration 83, loss = 0.51704811
# Iteration 84, loss = 0.51724399
# Iteration 85, loss = 0.51600843
# Iteration 86, loss = 0.51745109
# Iteration 87, loss = 0.51667113
# Iteration 88, loss = 0.51589774
# Iteration 89, loss = 0.51986209
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [[ 0 28]
#  [ 0 88]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        28
#            1       0.76      1.00      0.86        88
#
#     accuracy                           0.76       116
#    macro avg       0.38      0.50      0.43       116
# weighted avg       0.58      0.76      0.65       116
#
# Accuracy Using MLP: 0.7586206896551724
# /Users/kamil/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## plot learning curve

# %%
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    #http://scikit-learn.org/stable/auto_examples/model_selection/plot_learning_curve.html
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="r")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="g")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
             label="Cross-validation score")

    plt.legend(loc="best")
    plt.show()

# %%
#plot_learning_curve(mlp,"ILPD Learning", new_X_train, y_train)

# %%
print("Training set score: %f" % mlp.score(new_X_train, y_train))
print("Test set score: %f" % mlp.score(new_X_test, y_test))
# Out:
# Training set score: 0.704104
# Test set score: 0.758621

# %% [markdown]
# ## create a feature ranking (1)

# %%
X_train.head()
# Out:
#         Age  Gender        TB        DB   ALKPHOS      SGPT      SGOT  \
# 0  0.406977     1.0  0.083110  0.159341  0.082924  0.090452  0.320163
# 1  0.430233     1.0  0.030831  0.065934  0.282051  0.066332  0.019755
# 2  0.604651     1.0  0.009383  0.021978  0.063830  0.010050  0.010899
# 3  0.651163     1.0  0.037534  0.093407  0.374795  0.034673  0.045981
# 4  0.034884     1.0  0.001340  0.000000  0.157665  0.009045  0.013965
#
#          TP       ALB  AG Ratio
# 0  0.176471  0.173913     0.160
# 1  0.764706  0.673913     0.280
# 2  0.602941  0.630435     0.360
# 3  0.735294  0.500000     0.156
# 4  0.750000  0.717391     0.320

# %%
# use RFE to retrieve the 5 most informative features from the dataset
from sklearn.datasets import make_friedman1
from sklearn.feature_selection import RFE
from sklearn.svm import SVR

estimator = SVR(kernel="linear")
selector = RFE(estimator, n_features_to_select=5, step=1)
selector = selector.fit(X_train, y_train)
selector.support_


selector.ranking_
# Out:
# array([3, 6, 4, 2, 5, 1, 1, 1, 1, 1])

# %% [markdown]
# As we can see above the most informative features are:
# - SGPT
# - SGOT
# - TP
# - ALB
# - AG Ratio

# %% [markdown]
# ## create a frature ranking (2)

# %%
select_feature = SelectKBest(chi2, k=5).fit(X_train, y_train)

# %%
# lets try to leave only columns mentioned above
rfe_X_train = X_train.filter(['Age'], axis=1)
rfe_X_test = X_test.filter(['Age'], axis=1)

rfe_X_train.head()

# %% [markdown]
# ## new training and predictions

# %%
# create 2 layers of 20 nodes each + 2000 iterations
mlp = MLPClassifier(hidden_layer_sizes=(30), max_iter=2000, alpha=1e-4,
                  solver='adam', verbose=10, tol=1e-4, random_state=1,
                  learning_rate_init=0.01)

# train algorithm on training data
mlp.fit(rfe_X_train, y_train.values.ravel())

# make predictions
predictions = mlp.predict(rfe_X_test)

# accuracy score
acc = accuracy_score(y_test, predictions)

print(confusion_matrix(y_test,predictions))
print(classification_report(y_test, predictions))
print("Accuracy Using MLP: " + str(acc)+'\n')

# %%
#plot_learning_curve(mlp,"ILPD Learning", rfe_X_train, y_train)
